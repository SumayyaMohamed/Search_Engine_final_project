# %% [markdown]
#                                            **`SEMATIC SEARCH ENGINE PROJECT`**

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## **Step 1 - Reading the Tables from Database file**

# %%
# Read the code below and write your observation in the next cell

conn = sqlite3.connect('C:/Users/rjsek/OneDrive/Documents/Work and Professional documents/Innomatics Research Labs/Data Science Internship Jan 2024/Task - 9 Subtitle Search Engine/data/eng_subtitles_database.db')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
# Out:
# [('zipfiles',)]

# %% [markdown]
# **In the above cell, I am able to read the table inside the database. As mentioned earlier, table name is `zipfiles`. We also know from README.txt that this table contains three columns: 'num', 'name' and 'content'.**

# %% [markdown]
# ## **Step 2 - Reading the columns of Table**

# %%
cursor.execute("PRAGMA table_info('zipfiles')")
cols = cursor.fetchall()
for col in cols:
    print(col[1])
# Out:
# num
# name
# content

# %% [markdown]
# **The above code helps in checking the column names in the database table.**
#
# **Let's now use `SELECT * FROM zipfiles` to read all the data into a `df_30_percent_data` variable.**

# %% [markdown]
# ## **Step 3 - Loading the Database Table inside a Pandas DataFrame**

# %%
df_30_percent_data = pd.read_sql_query("""SELECT * FROM zipfiles""", conn)
df_30_percent_data = df_30_percent_data.sample(frac=0.3)
df_30_percent_data.head()
# Out:
#            num                                               name  \
# 68884  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 72341  9478254                             red.eye.(2005).eng.1cd
# 44918  9367553                                  10.(2022).eng.1cd
# 5016   9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 21135  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
#
#                                                  content
# 68884  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf5d\x9aV...
# 72341  b'PK\x03\x04\x14\x00\x00\x00\x08\x00*q\x9aV\xb...
# 44918  b'PK\x03\x04\x14\x00\x00\x00\x08\x00|\x0e\x9aV...
# 5016   b'PK\x03\x04\x14\x00\x00\x00\x08\x00d\x8d\x99V...
# 21135  b'PK\x03\x04\x14\x00\x00\x00\x08\x00*\x9d\x99V...

# %%
df_30_percent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24749 entries, 68884 to 23396
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   num      24749 non-null  int64
#  1   name     24749 non-null  object
#  2   content  24749 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 773.4+ KB

# %% [markdown]
# **Looks like the `content` column donot contain the subtitles text. Instead as mentioned in README.txt, it might be latin-1 encoded.**

# %% [markdown]
# ## **Step 4 - Printing `content` of 0th Row**

# %%
b_data = df_30_percent_data.iloc[0, 2]

# here 2 represent the index of content column
# 0 represents the row number

# %%
print(b_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf5d\x9aV5\xda\xb9\xd5RL\x00\x009\x83\x01\x00,\x00\x00\x00CSI Miami S09E01 Fallen.DVD.NonHI.en.CBS.ass\xbd}[\x92\xdb\xd6\x96\xe5\xbf#<\x07\xd8\x1f\xed\xbeQ)\x06\xf1\x06\xfcS!Y~d\xb5_a\xc9W\xe5\xaa\xdb\x1f \t&\xe1$\x01\x16\x00*M\xdf\xf0@j\n5\x85\xfe\xe8\xb9\xd4\x04z\n\xbd\x9f S<Ls\x0b\xd4\xad\xba\xb6\xb6e\x19+\x0fp\xce>\xfb\xb9\xf6\xff\xfb?\xff\xf7\xdf_\xcd\xdbj\xdb{\xb7\xf5\xb2\xf9\xdf\x1f\x7f\xf4\xba\xea\xd7\xe5\xe7\xde\xcbrY\xec\xd6\xbd\xb7\xac\xd6\xe5\xc7\x1f\xf1\x1fy\xbd\xdf\xc2\xbfy\x1bM\xa6\xd3\x7f\xfa\xf8\xa37m\xb1}\xd5\xef\xf1\x0fO?\xfe\xe8\xc7u\xb1\xff\xa9\xec\xfe\xf5s/\r\x0e\xff\xf8\xcb\xe7^\x94M\xf1\xbf/\xd6\xe5\xe2E\xd3.\xca\xf6y\xbdx\xb5*\x16\xcd\xc3\xe7\xde\xbe\xec>\xfe\xe8\xf9nQ5\xdeW\x15>\xe8\xe3\x8f\xfeZ-\xcaw\xff\xe9y\xb7-\xe7\xbd\xf7S\xd1W\r\x81\xf1o\xff[\xd3l>\xf7\x12\xfd\xc7\x1f\x9b\xae\x82?P\xd3\x9f\xf8\xf8\xa3\x7f\xffk\xf4O\x1e\xfd|\x1d\xac\xea\xab\xa6\xdd\x14\xfd\xe7\xde\xf7\xc5\xa6\xbc\xf1\xbej\xea\xbe\x1e\xa4\xae\xfa\x1d\xa4\x1f\xdbjS\xb4\xfb/\x9au\xb3ko\xbcW\xe5\xbc\xa9\x17G\xbf\xf1\xc3\xae_Wu\xa9\xff\xf8\xa2\x98\xdf\x0fr\xb3^\xdcx\xb7}\xb1\xae\xe67\xde\xcf5,\x12\xff(<\xa4o\xab\xfb\x12\xfeK\x10\xf1\r\xfc\xab\xfc\xfa\x0b\xfc\xba-\xe6U}w\xe3=\xaf\xef\xd6%>\x03\xdf\r\xfd\xbc\x03\x16\xfc)zQ\xf0\x87\xd6\xd5]\xbd)kx\xd0wE{W\xd5\xdf\xaa\xf0\x93\n\x7f\xbd\xf1\xbe\xac\xe7\xcd\x02\x1e\n\xef\x9b\xbf\xcb\xcb\xaaX7w\xbb\xd2\xbfy]\xac\x9aMq\x13\x067\xff\xe3\x9b\xe9\xf4\xab\x97\xf8\xff$\xe2\xff}\xf5\x15\x88\xfeW\xfc\x0f ~\x91\x8a\xa8\xff\xefO\xf9/\x92o\xfcI\x04\x7f\xa57\xc1M2\xc5\xff\xf9\xf1\x8d\x7f\x02\x19\x0c\x90\xe1?\n2\xfc\x07@\xc2\xbe\xfa\xf2-|\x87\xe3=\xf5m\xb1/q\xc7\xf4E\xdb\xe3GX\xdcx\xf2\x1dy\xb7=\xf5\xc5\x96K\xd8\xd97\xde\xeb\xf2\xb7\xfe\xe3\x8ft!\xb0\x83o\xa6\x9fO\xe1\x7f\xd9$OY\xf4\xa7\x93 \xbc9\xbc\xdd\x9f\xeb\xfb\xbay\xa8ox\x05\xc3\xdfn\xfe\xfe\xb7\xa2\x8e\xfe\xb6m\xba\xff\xe9g\xc9M\x98\xe7\x7f\xf9\xe3\x8bfSzM}\xe3\xdd\x95\xbd\xd7\xec\xe0\xaf\xa5\xd7\xafJ\xef\xa1\xd8\x7f\xe2\x00\xf5\xfdI\xa0\xa0\xf1$\xf6o\x0e\xef\xf7\x02\xd0(\xbb\t\x93\xf0/\x7f\xab\xfc?`\xf3\xde\x97pt\x8b\xb6\xf4\xbaU\xf3\xd0y\xbb\xce\xab\xea\xbf\xff\xad\x9a\xfe\xe1}Sl\xd6e\x7fs}\xfc\x98\x16\x8d\xf8m\t_\xea\xae\xf4\x16%(\xa3r\x01\xd0o\xab\xbe\xec\xbcM\xb1\xa8\xcb\xae\x9b\xd0\x0f\xe2\xf8\x01\x02\x7f\x92\x04"\xc6\x93<\xfeG\xbf\x80\x91\xf8Wx\x01\xc9d\x9a\x8b\x98O\x82\xc0\xf6\x03\xe4\x87\x1f\xe0\xbf\xff\xf3\xbf\xbc\x9f@!yE\xdb\xec\xea\x05\xed\xba\x16\xd44\xfc\x0c\xf0\xaf\xce\xc2\xe7\x930a1\x0c&\x99\r>\xf0\xb3G\xf0?6\xf3\xfb\xb2_\xee\xd6\xb8\xeb\xb7\x7f\x8a\r\x80\xb9b\xc3\xbb\x0fm\xd8q\x00\xd8\xd9\x80\xfd\xbc[\x95\xdd\x8dW\xe0/O\x82\xc2\xfbV\xd0l\x12Om\xa0!.8\x19@\xdf\x94^\xb1^{K\xfc\x1b\xdc\x1d\xf5\x93\xc0\xd9$\tY\x8c\xfcIh\\\xad\x1f>\xb9\xd3?\x08\xa8\x9f\xa5\xc3\xe7}\xe7$y\x7fw\xec\xf9s?\x04 G\xa2d\xa2p\x92\xa4\xc6\xef\x1c\r\xaf\xfc\xd23\x05(\x99/b4\x01\xd5l\x01\x0c\x03|\xd5S\x02|\xe6}\xd9Vs;\xce%WF\x10\xe7\xb0\xb0\xf4/\x00\xf2\xa6X\xf7e\xfb\x89\xfe\xeaB\x8a\'SEJPe\xdb\xb4D0|G\\\x0f\x98O^\xb1\xf1\xc08Z\xa3\xbe\xd87;o\x06\x16\xd6\xf9e&\x93H\xc1\xb3\x89?\xb5-3\x9c\xd2\xce\xfd\xe3\x0b<$p9"\xd4\x8d\xb7]\x97EWN\xae\x8e\x16\x07r\x0f\x0bZ[\xdd\xadz\x0f\xfe+\'T6\t"\x16c\xb8\xf2}#\x94\x7f\x80*\x01\xe6\x13O%\x17\x16\x00\x84\xb1\x88\xa0\xf7\x8cXi\xc4X\xdf\x94\xfb\x1bo%\x7fs\xc2\x84\x93\xa9\xc2\xc0\x96\x8c\x8d\xdf*\x7f\xbc$\x86\x01\xfb{\xe6\x06\x8b&y&b:\xf1m`~&\x9f\xea\xf6\xb3\x8dw\xd7\xd4uA6\x13\xeeF\xb1\x9bVe\xeb\xd8!>\xc0M\xe2\\D\xb8\xbe\x8d\xafR\x0e\xc3\x1f\xaf\xc0R\x9b5\x0b\x87YF\x8fM\x13\x11\xc3I\xfc>\x07\xfb\x08\x01\xdf\xe2z\xeb\xc2\xf1\xb3\xc94\x15\x11.\xe2\xc8\x84\x13N\xc5\xe6\xbc\x85\xd7G/\xce\xf5\xb2\xc0\xc0\t2\x11\xe1\x82\xb7\x1d\xa7\xcb \xa2`x[\xa0\x11s\xdb\xdb\xba\x04"\xc0\xb7\x93E,\xc2\x82|\x9bq\x1e\x86\xa2i\x9fW\xad\xeb\xe1`\x82E\x99\x88)^U\xd7|x\x98\x8a}\x07b>\x893\xdbV\n\xd8\xbe\xfb\xe3E[\x16`\xd0\xddx\xac\xbfg\xfc\x8fN\xbc|\x92\x06,F\xd3Ij;\x1c\xa1\xe2\xfdp_8N<=2KD\x0c\x10\xc8t\xe2\xfd\xe4\xb1z\x99x\x83\xbb\xd4=\x94%\xac\x88\xbc\xba\'V\x17\xa7bJ\x84xFc\xdbn\xf6s6\xa2xu\xdeA\xc9\x1d\xc0\xaf\x8e\ ...

# %% [markdown]
# **From the content, it appears to start with the bytes "PK\x03\......", which suggests that it might be a ZIP archive file. How do I know it? Experience! I have worked with something similar earlier.**

# %% [markdown]
# ## **Step 5 - Unzipping the content of 380th row and decoding using `latin-1`**

# %%
import zipfile
import io

# Assuming 'content' is the binary data from your database
binary_data = df_30_percent_data.iloc[380, 2]

# Decompress the binary data using the zipfile module
with io.BytesIO(binary_data) as f:
    with zipfile.ZipFile(f, 'r') as zip_file:
        # Reading only one file in the ZIP archive
        subtitle_content = zip_file.read(zip_file.namelist()[0])

# Now 'subtitle_content' should contain the extracted subtitle content
print(subtitle_content.decode('latin-1'))  # Assuming the content is latin-1 encoded text
# Out:
# ï»¿[Script Info]
# Title: Default file
# ScriptType: v4.00+
# WrapStyle: 0
# PlayResX: 720
# PlayResY: 480
# ScaledBorderAndShadow: yes
# Audio File:
# Video File:
# Video Aspect Ratio: 0
# Video Zoom: 6
# Video Position: 0
#
# [V4+ Styles]
# Format: Name, Fontname, Fontsize, PrimaryColour, SecondaryColour, OutlineColour, BackColour, Bold, Italic, Underline, StrikeOut, ScaleX, ScaleY, Spacing, Angle, BorderStyle, Outline, Shadow, Alignment, MarginL, MarginR, MarginV, Encoding
# Style: Dialogue1,Tahoma,30,&H00FDFDFD,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
# Style: Dialogue2,Tahoma,30,&H00FDFDFD,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
# Style: Dialogue4,Tahoma,30,&H00FDFDFD,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
# Style: Dialogue3,Tahoma,28,&H00FDFDFD,&H000000FF,&H1F000000,&HC7000000,0,0,0,0,100,100,0,0,1,1.4,1.7,2,60,60,15,1
#
# [Events]
# Format: Layer, Start, End, Style, Name, MarginL, MarginR, MarginV, Effect, Text
# Dialogue: 0,0:00:24.25,0:00:28.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(187,394)}Good evening, and thank you
# Dialogue: 0,0:00:24.25,0:00:28.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(187,431)}for peeping in at me tonight.
# Dialogue: 0,0:00:28.89,0:00:31.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,394)}I shall try to make it
# Dialogue: 0,0:00:28.89,0:00:31.59,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,431)}worth your while.
# Dialogue: 0,0:00:32.09,0:00:35.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,357)}Now, if you will
# Dialogue: 0,0:00:32.09,0:00:35.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,394)}look through the keyhole
# Dialogue: 0,0:00:32.09,0:00:35.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,431)}with your other eye....
# Dialogue: 0,0:00:43.01,0:00:45.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,431)}Excellent. Thank you.
# Dialogue: 0,0:00:45.64,0:00:47.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,431)}Incidentally, those of you...
# Dialogue: 0,0:00:47.98,0:00:51.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,354)}who think these letters
# Dialogue: 0,0:00:47.98,0:00:51.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,394)}don't spell anything
# Dialogue: 0,0:00:47.98,0:00:51.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,428)}couldn't be more incorrect.
# Dialogue: 0,0:00:52.15,0:00:56.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,394)}The last line was copied
# Dialogue: 0,0:00:52.15,0:00:56.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,431)}from an old insurance policy.
# Dialogue: 0,0:00:57.35,0:00:59.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,391)}Now that
# Dialogue: 0,0:00:57.35,0:00:59.38,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,428)}we are all in focus...
# Dialogue: 0,0:00:59.45,0:01:03.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,354)}I should like to make
# Dialogue: 0,0:00:59.45,0:01:03.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,394)}a few preparatory remarks
# Dialogue: 0,0:00:59.45,0:01:03.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,431)}about tonight's librette.
# Dialogue: 0,0:01:04.13,0:01:06.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(198,431)}It is called {\i1}The Creeper...{\i0}
# Dialogue: 0,0:01:06.70,0:01:09.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,394)}and is about a person
# Dialogue: 0,0:01:06.70,0:01:09.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(181,431)}who had a very peculiar way...
# Dialogue: 0,0:01:09.90,0:01:12.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,394)}of striking up
# Dialogue: 0,0:01:09.90,0:01:12.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,431)}an acquaintance with women:
# Dialogue: 0,0:01:13.54,0:01:14.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(261,428)}He killed them.
# Dialogue: 0,0:01:15.57,0:01:18.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,394)}A distinctly
# Dialogue: 0,0:01:15.57,0:01:18.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(237,431)}antisocial tendency...
# Dialogue: 0,0:01:18.87,0:01:21.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(214,391)}for it never leads
# Dialogue: 0,0:01:18.87,0:01:21.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,431)}to any lasting friendship.
# Dialogue: 0,0:01:54.48,0:01:58.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(438,382)}Hot, ain't it?
# Dialogue: 0,0:01:54.48,0:01:58.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,431)}The worst we've had yet.
# Dialogue: 0,0:01:59.72,0:02:03.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(156,345)}You're the new janitor,
# Dialogue: 0,0:01:59.72,0:02:03.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(157,382)}aren't you?
# Dialogue: 0,0:01:59.72,0:02:03.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,431)}At your service, Mrs. Stone.
# Dialogue: 0,0:02:04.12,0:02:06.18,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,394)}Anytime
# Dialogue: 0,0:02:04.12,0:02:06.18,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,431)}you want anything done...
# Dialogue: 0,0:02:06.25,0:02:08.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,394)}you just yell for old George,
# Dialogue: 0,0:02:06.25,0:02:08.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(195,428)}and he'll take care of it.
# Dialogue: 0,0:02:10.03,0:02:14.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,345)}"Satisfaction guaranteed."
# Dialogue: 0,0:02:10.03,0:02:14.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,382)}That's my motto.
# Dialogue: 0,0:02:10.03,0:02:14.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(179,428)}That'll last about a week.
# Dialogue: 0,0:02:15.33,0:02:17.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,394)}Then you'll be
# Dialogue: 0,0:02:15.33,0:02:17.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(211,431)}just like all the others.
# Dialogue: 0,0:02:20.94,0:02:24.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,394)}Terrible thing, ain't it?
# Dialogue: 0,0:02:20.94,0:02:24.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,431)}Them poor women.
# Dialogue: 0,0:02:24.97,0:02:27.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(167,431)}They probably asked for it.
# Dialogue: 0,0:02:28.01,0:02:30.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,391)}Decent women
# Dialogue: 0,0:02:28.01,0:02:30.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,431)}don't get themselves murdered.
# Dialogue: 0,0:02:35.72,0:02:37.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,379)}Hello.
# Dialogue: 0,0:02:35.72,0:02:37.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(298,431)}Hello, Mrs. Grant.
# Dialogue: 0,0:02:38.05,0:02:41.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,382)}Feeling better?
# Dialogue: 0,0:02:38.05,0:02:41.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,431)}Yes, a lot, thanks.
# Dialogue: 0,0:02:42.09,0:02:45.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(149,342)}I think it's the heat
# Dialogue: 0,0:02:42.09,0:02:45.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(148,382)}as much as anything.
# Dialogue: 0,0:02:42.09,0:02:45.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,431)}Terrible, isn't it?
# Dialogue: 0,0:02:45.86,0:02:49.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,357)}After a week of this,
# Dialogue: 0,0:02:45.86,0:02:49.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(157,391)}it's a wonder
# Dialogue: 0,0:02:45.86,0:02:49.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,428)}we're not all sick.
# Dialogue: 0,0:02:49.46,0:02:53.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,357)}Paper says there's going
# Dialogue: 0,0:02:49.46,0:02:53.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,394)}to be a storm tonight.
# Dialogue: 0,0:02:49.46,0:02:53.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(214,431)}That'll break it up a little.
# Dialogue: 0,0:02:53.27,0:02:56.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(164,382)}Aren't you the new janitor?
# Dialogue: 0,0:02:53.27,0:02:56.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(278,431)}At your service, ma'am.
# Dialogue: 0,0:02:56.27,0:02:57.74,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,391)}I wonder
# Dialogue: 0,0:02:56.27,0:02:57.74,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,431)}if you'd do me a favor.
# Dialogue: 0,0:02:58.94,0:03:01.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(176,394)}I've been trying for two days
# Dialogue: 0,0:02:58.94,0:03:01.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,431)}to get somebody...
# Dialogue: 0,0:03:01.11,0:03:02.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,391)}to come from
# Dialogue: 0,0:03:01.11,0:03:02.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,428)}the hardware store...
# Dialogue: 0,0:03:02.58,0:03:05.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,394)}and put a bolt and chain
# Dialogue: 0,0:03:02.58,0:03:05.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,428)}on the inside of the door.
# Dialogue: 0,0:03:05.21,0:03:06.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(396,394)}They've all been
# Dialogue: 0,0:03:05.21,0:03:06.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(397,431)}pretty busy.
# Dialogue: 0,0:03:06.85,0:03:09.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,391)}A lot of nervous women
# Dialogue: 0,0:03:06.85,0:03:09.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(277,431)}in this neighborhood...
# Dialogue: 0,0:03:09.08,0:03:11.21,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(368,394)}got the same idea
# Dialogue: 0,0:03:09.08,0:03:11.21,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(368,428)}at the same time.
# Dialogue: 0,0:03:11.29,0:03:13.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(334,394)}But don't you worry,
# Dialogue: 0,0:03:11.29,0:03:13.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(334,428)}Mrs. Grant.
# Dialogue: 0,0:03:13.56,0:03:18.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,357)}If anyone bothers you,
# Dialogue: 0,0:03:13.56,0:03:18.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,394)}you just yell for old George,
# Dialogue: 0,0:03:13.56,0:03:18.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(195,428)}and he'll take care of them.
# Dialogue: 0,0:03:21.73,0:03:25.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(335,391)}I don't like him.
# Dialogue: 0,0:03:21.73,0:03:25.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(335,428)}He smiles too much.
# Dialogue: 0,0:03:25.30,0:03:28.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,382)}Your husband gone to work?
# Dialogue: 0,0:03:25.30,0:03:28.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(305,431)}Not yet.
# Dialogue: 0,0:03:28.74,0:03:30.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(317,382)}Why?
# Dialogue: 0,0:03:28.74,0:03:30.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(376,431)}No reason, but...
# Dialogue: 0,0:03:31.31,0:03:33.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(350,354)}I should think
# Dialogue: 0,0:03:31.31,0:03:33.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(348,394)}you'd be afraid
# Dialogue: 0,0:03:31.31,0:03:33.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(348,431)}to stay alone...
# Dialogue: 0,0:03:33.84,0:03:36.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,394)}so much of the night
# Dialogue: 0,0:03:33.84,0:03:36.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(330,431)}the way you do.
# Dialogue: 0,0:03:36.75,0:03:40.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,354)}Both of those
# Dialogue: 0,0:03:36.75,0:03:40.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,391)}other women's husbands
# Dialogue: 0,0:03:36.75,0:03:40.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,431)}were on night shifts, too.
# Dialogue: 0,0:03:41.28,0:03:43.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(296,391)}Thanks a lot.
# Dialogue: 0,0:03:41.28,0:03:43.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(295,431)}You're a big help.
# Dialogue: 0,0:03:44.82,0:03:48.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,357)}I'll come by
# Dialogue: 0,0:03:44.82,0:03:48.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(322,394)}and see you later,
# Dialogue: 0,0:03:44.82,0:03:48.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,431)}keep you company.
# Dialogue: 0,0:03:55.20,0:03:57.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,394)}Window doesn't help much,
# Dialogue: 0,0:03:55.20,0:03:57.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,428)}does it?
# Dialogue: 0,0:03:57.20,0:03:59.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,394)}It doesn't help these eggs,
# Dialogue: 0,0:03:57.20,0:03:59.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,428)}that's for sure.
# Dialogue: 0,0:04:00.17,0:04:01.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(302,394)}Now, what's the matter
# Dialogue: 0,0:04:00.17,0:04:01.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(300,431)}with the eggs?
# Dialogue: 0,0:04:01.84,0:04:03.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(147,394)}They're just no good,
# Dialogue: 0,0:04:01.84,0:04:03.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(146,428)}that's all.
# Dialogue: 0,0:04:03.31,0:04:05.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,394)}Well, they're no different
# Dialogue: 0,0:04:03.31,0:04:05.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,431)}than they are every day.
# Dialogue: 0,0:04:05.41,0:04:07.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,431)}You can say that again.
# Dialogue: 0,0:04:08.04,0:04:09.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(244,394)}Why you can't do
# Dialogue: 0,0:04:08.04,0:04:09.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,431)}a simple thing...
# Dialogue: 0,0:04:09.68,0:04:12.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(228,354)}like scramble
# Dialogue: 0,0:04:09.68,0:04:12.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,394)}a couple of eggs,
# Dialogue: 0,0:04:09.68,0:04:12.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(228,428)}I'll never know.
# Dialogue: 0,0:04:12.08,0:04:13.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,431)}All right, Steve, all right.
# Dialogue: 0,0:04:14.55,0:04:16.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,357)}It's hot,
# Dialogue: 0,0:04:14.55,0:04:16.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(274,394)}and we're both on edge.
# Dialogue: 0,0:04:14.55,0:04:16.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,431)}Now, let's drop it, huh?
# Dialogue: 0,0:04:16.95,0:04:18.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,394)}Speak for yourself.
# Dialogue: 0,0:04:16.95,0:04:18.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(250,431)}Just because you...
# Dialogue: 0,0:04:18.69,0:04:20.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,394)}and a lot of other crazy dames
# Dialogue: 0,0:04:18.69,0:04:20.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,431)}in this neighborhood...
# Dialogue: 0,0:04:20.92,0:04:22.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,394)}think they're gonna
# Dialogue: 0,0:04:20.92,0:04:22.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,428)}be murdered...
# Dialogue: 0,0:04:22.26,0:04:23.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,394)}doesn't mean I'm crazy, too,
# Dialogue: 0,0:04:22.26,0:04:23.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(179,428)}Ellen.
# Dialogue: 0,0:04:23.73,0:04:26.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,394)}What's so crazy about it?
# Dialogue: 0,0:04:23.73,0:04:26.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(238,431)}It could happen, you know.
# Dialogue: 0,0:04:27.60,0:04:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(166,354)}This isn't
# Dialogue: 0,0:04:27.60,0:04:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(164,394)}just one of those things
# Dialogue: 0,0:04:27.60,0:04:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,431)}you read in the newspaper.
# Dialogue: 0,0:04:32.23,0:04:34.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,391)}Both those women lived
# Dialogue: 0,0:04:32.23,0:04:34.50,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,428)}about five blocks from here.
# Dialogue: 0,0:04:34.57,0:04:37.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,382)}So keep the door locked.
# Dialogue: 0,0:04:34.57,0:04:37.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,431)}A kid could open that lock.
# Dialogue: 0,0:04:38.51,0:04:40.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,394)}That's why I want
# Dialogue: 0,0:04:38.51,0:04:40.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,431)}a bolt and chain put on it.
# Dialogue: 0,0:04:40.54,0:04:43.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(203,394)}All right, get one. Get two
# Dialogue: 0,0:04:40.54,0:04:43.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,431)}if it'll make you feel better.
# Dialogue: 0,0:04:45.48,0:04:48.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,394)}Boy.
# Dialogue: 0,0:04:45.48,0:04:48.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(167,431)}You're in a great mood today.
# Dialogue: 0,0:04:48.38,0:04:50.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,394)}I'm all right.
# Dialogue: 0,0:04:48.38,0:04:50.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(154,428)}Just leave me alone.
# Dialogue: 0,0:04:50.29,0:04:52.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(256,431)}I didn't saying anything.
# Dialogue: 0,0:04:53.19,0:04:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(171,394)}Ellen, didn't you pick up
# Dialogue: 0,0:04:53.19,0:04:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(171,431)}my other pair of work shoes?
# Dialogue: 0,0:04:56.66,0:04:58.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(357,382)}I forgot.
# Dialogue: 0,0:04:56.66,0:04:58.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,431)}You forgot.
# Dialogue: 0,0:04:59.73,0:05:02.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,394)}What do you want me to do,
# Dialogue: 0,0:04:59.73,0:05:02.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,431)}work in my bare feet?
# Dialogue: 0,0:05:02.36,0:05:05.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,357)}Will you please pick them up?
# Dialogue: 0,0:05:02.36,0:05:05.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,394)}You haven't got
# Dialogue: 0,0:05:02.36,0:05:05.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,431)}anything else to do.
# Dialogue: 0,0:05:05.83,0:05:07.74,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,431)}Now, you cut that out, Steve.
# Dialogue: 0,0:05:08.74,0:05:11.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(276,357)}It isn't my fault
# Dialogue: 0,0:05:08.74,0:05:11.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(274,394)}that you didn't
# Dialogue: 0,0:05:08.74,0:05:11.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(275,431)}get the raise, you know.
# Dialogue: 0,0:05:11.07,0:05:12.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(421,394)}You just stop
# Dialogue: 0,0:05:11.07,0:05:12.63,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(423,431)}picking on me.
# Dialogue: 0,0:05:12.71,0:05:14.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,345)}Hell,
# Dialogue: 0,0:05:12.71,0:05:14.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,382)}nobody's picking on you.
# Dialogue: 0,0:05:12.71,0:05:14.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(479,428)}You are!
# Dialogue: 0,0:05:14.38,0:05:17.84,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,354)}You have been.
# Dialogue: 0,0:05:14.38,0:05:17.84,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,394)}You've been snapping at me
# Dialogue: 0,0:05:14.38,0:05:17.84,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(231,431)}ever since you got up.
# Dialogue: 0,0:05:24.09,0:05:26.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(302,357)}I've been wanting
# Dialogue: 0,0:05:24.09,0:05:26.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(300,394)}to ask you to
# Dialogue: 0,0:05:24.09,0:05:26.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,431)}do something for me...
# Dialogue: 0,0:05:26.66,0:05:28.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(429,391)}and I'm afraid
# Dialogue: 0,0:05:26.66,0:05:28.02,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(428,428)}to mention it.
# Dialogue: 0,0:05:28.09,0:05:30.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,391)}I don't know
# Dialogue: 0,0:05:28.09,0:05:30.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(171,431)}what you're talking about.
# Dialogue: 0,0:05:30.36,0:05:32.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(145,394)}What do you want from me,
# Dialogue: 0,0:05:30.36,0:05:32.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(147,428)}Ellen?
# Dialogue: 0,0:05:33.63,0:05:35.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(334,394)}Ask them to put you
# Dialogue: 0,0:05:33.63,0:05:35.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(335,431)}on the day shift.
# Dialogue: 0,0:05:36.73,0:05:38.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(338,357)}Please, Steve.
# Dialogue: 0,0:05:36.73,0:05:38.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(338,394)}Please, just for
# Dialogue: 0,0:05:36.73,0:05:38.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(337,431)}a couple of weeks...
# Dialogue: 0,0:05:38.90,0:05:40.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(403,394)}until the police
# Dialogue: 0,0:05:38.90,0:05:40.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(402,431)}catch this guy.
# Dialogue: 0,0:05:40.40,0:05:44.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(280,355)}Are you kidding?
# Dialogue: 0,0:05:40.40,0:05:44.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(338,394)}No, I'm not kidding!
# Dialogue: 0,0:05:40.40,0:05:44.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(338,428)}I'm scared!
# Dialogue: 0,0:05:45.44,0:05:47.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,394)}Every time you go out
# Dialogue: 0,0:05:45.44,0:05:47.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(252,428)}and I'm alone here...
# Dialogue: 0,0:05:47.94,0:05:50.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,394)}I jump at every sound I hear
# Dialogue: 0,0:05:47.94,0:05:50.34,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,428)}in the hall.
# Dialogue: 0,0:05:50.68,0:05:53.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,357)}What would you like
# Dialogue: 0,0:05:50.68,0:05:53.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(201,391)}for me to do?
# Dialogue: 0,0:05:50.68,0:05:53.81,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(201,431)}Sit and hold your hand?
# Dialogue: 0,0:05:53.88,0:05:54.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(458,431)}Forget it.
# Dialogue: 0,0:05:55.82,0:05:59.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(279,345)}Just finish your supper
# Dialogue: 0,0:05:55.82,0:05:59.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(279,382)}and forget it.
# Dialogue: 0,0:05:55.82,0:05:59.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,431)}"Finish your supper."
# Dialogue: 0,0:05:59.96,0:06:02.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(181,394)}Who's got an appetite
# Dialogue: 0,0:05:59.96,0:06:02.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(181,431)}with you sitting here yakking?
# Dialogue: 0,0:06:03.26,0:06:06.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(156,394)}I'm going to work.
# Dialogue: 0,0:06:03.26,0:06:06.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(154,431)}And please get the shoes.
# Dialogue: 0,0:06:12.30,0:06:13.67,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(253,431)}Goodbye, Ellen.
# Dialogue: 0,0:06:15.57,0:06:16.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(364,431)}Goodbye.
# Dialogue: 0,0:06:54.81,0:06:59.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,394)}Hello, Mr. Gibbons?
# Dialogue: 0,0:06:54.81,0:06:59.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,431)}This is Ellen Grant again.
# Dialogue: 0,0:07:00.32,0:07:02.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,394)}Well, yes,
# Dialogue: 0,0:07:00.32,0:07:02.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,431)}I know you're busy...
# Dialogue: 0,0:07:02.55,0:07:03.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,394)}but if you can't come
# Dialogue: 0,0:07:02.55,0:07:03.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,431)}yourself...
# Dialogue: 0,0:07:03.85,0:07:05.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,394)}do you think you could
# Dialogue: 0,0:07:03.85,0:07:05.91,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(186,431)}possibly send somebody...
# Dialogue: 0,0:07:05.99,0:07:08.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(213,394)}who could put a chain
# Dialogue: 0,0:07:05.99,0:07:08.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(214,428)}on that door?
# Dialogue: 0,0:07:08.92,0:07:11.66,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(172,431)}Would you? I'd appreciate it.
# Dialogue: 0,0:07:11.73,0:07:12.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(312,428)}What?
# Dialogue: 0,0:07:14.16,0:07:16.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,394)}No, I'm feeling better,
# Dialogue: 0,0:07:14.16,0:07:16.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,431)}thank you.
# Dialogue: 0,0:07:16.50,0:07:19.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,357)}Just nervous,
# Dialogue: 0,0:07:16.50,0:07:19.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,394)}like everybody else
# Dialogue: 0,0:07:16.50,0:07:19.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,431)}in the neighborhood, I guess.
# Dialogue: 0,0:07:20.90,0:07:23.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(209,431)}Yes, thank you. Goodbye.
# Dialogue: 0,0:07:37.22,0:07:38.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(291,428)}Who is that?
# Dialogue: 0,0:07:43.93,0:07:47.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(288,352)}Who is it?
# Dialogue: 0,0:07:43.93,0:07:47.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,431)}It's only me, Mrs. Grant.
# Dialogue: 0,0:07:54.07,0:07:58.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(358,355)}What do you want?
# Dialogue: 0,0:07:54.07,0:07:58.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,394)}Nothing. I saw
# Dialogue: 0,0:07:54.07,0:07:58.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,431)}your husband leaving, and...
# Dialogue: 0,0:07:58.31,0:08:01.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,357)}wondered if you wanted me
# Dialogue: 0,0:07:58.31,0:08:01.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,394)}to come over this evening
# Dialogue: 0,0:07:58.31,0:08:01.90,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(145,431)}and stay with you.
# Dialogue: 0,0:08:01.98,0:08:03.54,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,394)}No, thanks.
# Dialogue: 0,0:08:01.98,0:08:03.54,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,431)}I'll be all right. Thanks.
# Dialogue: 0,0:08:03.61,0:08:06.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,394)}My Joe's gonna be
# Dialogue: 0,0:08:03.61,0:08:06.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(161,431)}working overtime, and....
# Dialogue: 0,0:08:06.28,0:08:08.08,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,394)}Well, you kind of acted
# Dialogue: 0,0:08:06.28,0:08:08.08,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(156,431)}so funny before.
# Dialogue: 0,0:08:08.15,0:08:12.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(171,357)}I thought you might be afraid
# Dialogue: 0,0:08:08.15,0:08:12.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,394)}to stay alone,
# Dialogue: 0,0:08:08.15,0:08:12.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,431)}didn't like to say so.
# Dialogue: 0,0:08:12.35,0:08:14.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,394)}But if you're not
# Dialogue: 0,0:08:12.35,0:08:14.45,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,428)}nervous about it....
# Dialogue: 0,0:08:14.52,0:08:16.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(314,391)}Of course
# Dialogue: 0,0:08:14.52,0:08:16.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(315,428)}I'm nervous about it.
# Dialogue: 0,0:08:17.06,0:08:18.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,431)}Isn't everybody? Aren't you?
# Dialogue: 0,0:08:20.66,0:08:21.69,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(188,428)}No.
# Dialogue: 0,0:08:22.50,0:08:24.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(152,394)}I have nothing
# Dialogue: 0,0:08:22.50,0:08:24.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,428)}to be nervous about.
# Dialogue: 0,0:08:26.07,0:08:28.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,394)}You don't get murdered
# Dialogue: 0,0:08:26.07,0:08:28.47,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,428)}without a reason.
# Dialogue: 0,0:08:29.20,0:08:31.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(172,394)}As a matter of fact,
# Dialogue: 0,0:08:29.20,0:08:31.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,431)}some of the papers said...
# Dialogue: 0,0:08:31.67,0:08:33.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(137,394)}it might be a woman
# Dialogue: 0,0:08:31.67,0:08:33.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(135,428)}who killed them.
# Dialogue: 0,0:08:33.51,0:08:35.07,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(151,431)}Some woman who was jealous...
# Dialogue: 0,0:08:35.14,0:08:38.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(127,354)}about her husband
# Dialogue: 0,0:08:35.14,0:08:38.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(127,394)}getting involved
# Dialogue: 0,0:08:35.14,0:08:38.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(126,428)}with other women.
# Dialogue: 0,0:08:40.08,0:08:43.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(281,357)}That's about as silly as
# Dialogue: 0,0:08:40.08,0:08:43.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(281,391)}all the theories
# Dialogue: 0,0:08:40.08,0:08:43.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(282,431)}in the newspapers.
# Dialogue: 0,0:08:43.39,0:08:47.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,394)}I don't know. I can't say
# Dialogue: 0,0:08:43.39,0:08:47.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,428)}I blame her if it's true.
# Dialogue: 0,0:08:49.59,0:08:53.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,391)}Women like that deserve
# Dialogue: 0,0:08:49.59,0:08:53.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(176,431)}anything that happens to them.
# Dialogue: 0,0:08:55.36,0:08:56.76,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(145,428)}What's the matter?
# Dialogue: 0,0:08:57.23,0:08:58.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(381,431)}Uh, well...
# Dialogue: 0,0:08:58.60,0:09:00.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(324,431)}nothing. It's just....
# Dialogue: 0,0:09:01.64,0:09:02.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(359,431)}I have to go out.
# Dialogue: 0,0:09:02.90,0:09:05.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,394)}I didn't know you were
# Dialogue: 0,0:09:02.90,0:09:05.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(156,431)}well enough to go out.
# Dialogue: 0,0:09:05.34,0:09:06.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(357,431)}Well, it's not far.
# Dialogue: 0,0:09:07.31,0:09:09.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(361,431)}Excuse me, please.
# Dialogue: 0,0:09:12.21,0:09:14.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,382)}Hi, Steve.
# Dialogue: 0,0:09:12.21,0:09:14.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(474,431)}Hi, Ed.
# Dialogue: 0,0:09:14.62,0:09:16.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(297,382)}How's things with you?
# Dialogue: 0,0:09:14.62,0:09:16.92,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,431)}Pretty good.
# Dialogue: 0,0:09:16.99,0:09:18.35,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(245,431)\i1}âªâª{\i0}
# Dialogue: 0,0:09:18.42,0:09:21.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(141,355)}You off tonight?
# Dialogue: 0,0:09:18.42,0:09:21.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,394)}No, no, just having a beer
# Dialogue: 0,0:09:18.42,0:09:21.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,431)}before I go in.
# Dialogue: 0,0:09:22.12,0:09:24.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(396,382)}How about you?
# Dialogue: 0,0:09:22.12,0:09:24.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,428)}Yeah.
# Dialogue: 0,0:09:24.23,0:09:25.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(484,428)}Joe?
# Dialogue: 0,0:09:26.06,0:09:29.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(303,345)}How's everything in
# Dialogue: 0,0:09:26.06,0:09:29.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,382)}the newspaper racket?
# Dialogue: 0,0:09:26.06,0:09:29.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,428)}Dull.
# Dialogue: 0,0:09:30.70,0:09:33.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,354)}Unless our friend here
# Dialogue: 0,0:09:30.70,0:09:33.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,394)}knocks off somebody else
# Dialogue: 0,0:09:30.70,0:09:33.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(155,432)}pretty soon...
# Dialogue: 0,0:09:33.37,0:09:35.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,342)}he'll be
# Dialogue: 0,0:09:33.37,0:09:35.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,382)}pushed off the front page.
# Dialogue: 0,0:09:33.37,0:09:35.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,431)}You mean The Creeper?
# Dialogue: 0,0:09:35.84,0:09:39.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,357)}We're running out of things
# Dialogue: 0,0:09:35.84,0:09:39.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,394)}to say about him.
# Dialogue: 0,0:09:35.84,0:09:39.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,431)}Even running out of theories.
# Dialogue: 0,0:09:40.04,0:09:41.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,394)}Next,
# Dialogue: 0,0:09:40.04,0:09:41.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,431)}he'll be running out of women.
# Dialogue: 0,0:09:42.04,0:09:44.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,394)}You think that's real funny,
# Dialogue: 0,0:09:42.04,0:09:44.48,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,431)}don't you?
# Dialogue: 0,0:09:45.05,0:09:46.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,391)}But Ellen's
# Dialogue: 0,0:09:45.05,0:09:46.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(266,431)}practically hysterical...
# Dialogue: 0,0:09:46.65,0:09:49.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(215,394)}just like every other woman
# Dialogue: 0,0:09:46.65,0:09:49.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,431)}in the neighborhood.
# Dialogue: 0,0:09:49.42,0:09:51.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(149,394)}Well, they don't have
# Dialogue: 0,0:09:49.42,0:09:51.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(151,428)}much excitement.
# Dialogue: 0,0:09:51.52,0:09:53.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,391)}Have to make the most
# Dialogue: 0,0:09:51.52,0:09:53.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,431)}of something like this.
# Dialogue: 0,0:09:53.79,0:09:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(210,357)}Brother,
# Dialogue: 0,0:09:53.79,0:09:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(208,391)}what a weird sense of humor
# Dialogue: 0,0:09:53.79,0:09:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(208,431)}you've got!
# Dialogue: 0,0:09:56.86,0:09:59.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(148,394)}"Warped" is the word
# Dialogue: 0,0:09:56.86,0:09:59.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(147,431)}you're looking for.
# Dialogue: 0,0:10:00.23,0:10:03.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,355)}Used to bother Ellen, too.
# Dialogue: 0,0:10:00.23,0:10:03.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(334,394)}Well, sure!
# Dialogue: 0,0:10:00.23,0:10:03.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(336,431)}It'd bother anybody.
# Dialogue: 0,0:10:04.33,0:10:07.06,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(218,357)}You know, Ed, I don't think
# Dialogue: 0,0:10:04.33,0:10:07.06,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,391)}either one of us
# Dialogue: 0,0:10:04.33,0:10:07.06,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,431)}are a bargain...
# Dialogue: 0,0:10:07.14,0:10:09.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,391)}but I think Ellen's better off
# Dialogue: 0,0:10:07.14,0:10:09.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,428)}married to me.
# Dialogue: 0,0:10:09.77,0:10:12.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(334,391)}Even if she wouldn't
# Dialogue: 0,0:10:09.77,0:10:12.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(333,431)}admit it right now.
# Dialogue: 0,0:10:12.61,0:10:14.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,345)}What's the matter,
# Dialogue: 0,0:10:12.61,0:10:14.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,382)}you had a fight?
# Dialogue: 0,0:10:12.61,0:10:14.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(533,428)}Yeah.
# Dialogue: 0,0:10:14.88,0:10:17.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(286,394)}I got up feeling rough
# Dialogue: 0,0:10:14.88,0:10:17.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(285,428)}and took it out on her.
# Dialogue: 0,0:10:18.88,0:10:22.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(327,342)}This weather.
# Dialogue: 0,0:10:18.88,0:10:22.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(328,382)}It's hot. It's sticky.
# Dialogue: 0,0:10:18.88,0:10:22.65,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,428)}What's the matter with it?
# Dialogue: 0,0:10:23.12,0:10:25.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,379)}I kind of like it.
# Dialogue: 0,0:10:23.12,0:10:25.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(388,431)}Yeah, you would.
# Dialogue: 0,0:10:26.62,0:10:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(199,357)}I guess it's not the weather.
# Dialogue: 0,0:10:26.62,0:10:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(199,394)}I was looking for a raise,
# Dialogue: 0,0:10:26.62,0:10:30.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(198,431)}and I didn't get it.
# Dialogue: 0,0:10:31.99,0:10:34.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(142,379)}Took it out on her?
# Dialogue: 0,0:10:31.99,0:10:34.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(479,428)}Yeah.
# Dialogue: 0,0:10:34.73,0:10:38.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(307,357)}Why do we do it, Ed?
# Dialogue: 0,0:10:34.73,0:10:38.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(307,394)}Why do we take it out
# Dialogue: 0,0:10:34.73,0:10:38.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,431)}on somebody else?
# Dialogue: 0,0:10:38.20,0:10:40.03,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,431)}Especially someone you love.
# Dialogue: 0,0:10:41.24,0:10:44.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(131,382)}Very simple.
# Dialogue: 0,0:10:41.24,0:10:44.17,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(392,431)}Simple?
# Dialogue: 0,0:10:45.24,0:10:48.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(152,342)}No one else
# Dialogue: 0,0:10:45.24,0:10:48.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,382)}would put up with it.
# Dialogue: 0,0:10:45.24,0:10:48.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,431)}Yeah, I guess you're right.
# Dialogue: 0,0:10:48.88,0:10:50.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(153,431)}Don't worry about it.
# Dialogue: 0,0:10:51.35,0:10:54.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,394)}Everybody takes out
# Dialogue: 0,0:10:51.35,0:10:54.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,431)}his grudges on somebody else.
# Dialogue: 0,0:10:54.55,0:10:56.28,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(154,431)}Usually the wrong person.
# Dialogue: 0,0:10:58.05,0:10:59.58,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(151,428)}Take our friend here.
# Dialogue: 0,0:11:00.12,0:11:02.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(162,354)}He takes it out
# Dialogue: 0,0:11:00.12,0:11:02.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(162,394)}by killing the woman
# Dialogue: 0,0:11:00.12,0:11:02.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(162,431)}he's got something against.
# Dialogue: 0,0:11:02.82,0:11:04.62,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(327,431)}I didn't go that far.
# Dialogue: 0,0:11:04.69,0:11:07.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,354)}You think
# Dialogue: 0,0:11:04.69,0:11:07.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(301,394)}they'll catch this guy
# Dialogue: 0,0:11:04.69,0:11:07.46,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(302,431)}anywheres near soon?
# Dialogue: 0,0:11:07.53,0:11:10.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(164,391)}Who knows?
# Dialogue: 0,0:11:07.53,0:11:10.23,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(166,431)}Haven't got much to go on.
# Dialogue: 0,0:11:12.67,0:11:15.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,394)}About the only connection
# Dialogue: 0,0:11:12.67,0:11:15.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(167,428)}between those two women was...
# Dialogue: 0,0:11:16.07,0:11:19.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(183,394)}they were both alone at night,
# Dialogue: 0,0:11:16.07,0:11:19.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(184,431)}and they were both blonde.
# Dialogue: 0,0:11:24.41,0:11:28.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(145,379)}What's the matter?
# Dialogue: 0,0:11:24.41,0:11:28.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(195,431)}Nothing. I was just thinking.
# Dialogue: 0,0:11:29.12,0:11:31.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(369,394)}Ellen's alone,
# Dialogue: 0,0:11:29.12,0:11:31.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(368,428)}and she's blonde.
# Dialogue: 0,0:11:39.83,0:11:41.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,394)}What are you staring at me
# Dialogue: 0,0:11:39.83,0:11:41.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,428)}like that for?
# Dialogue: 0,0:11:41.90,0:11:44.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(179,394)}Nothing wrong with looking
# Dialogue: 0,0:11:41.90,0:11:44.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,431)}at a pretty woman, is there?
# Dialogue: 0,0:11:45.80,0:11:49.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,345)}Would you please
# Dialogue: 0,0:11:45.80,0:11:49.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(332,382)}get me these shoes?
# Dialogue: 0,0:11:45.80,0:11:49.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(160,431)}Be glad to.
# Dialogue: 0,0:11:51.64,0:11:53.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,394)}Did you hear the latest
# Dialogue: 0,0:11:51.64,0:11:53.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,431)}about The Creeper?
# Dialogue: 0,0:11:53.94,0:11:57.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,354)}Police seem to think
# Dialogue: 0,0:11:53.94,0:11:57.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,391)}he's a man who works
# Dialogue: 0,0:11:53.94,0:11:57.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,431)}locally around here.
# Dialogue: 0,0:11:57.38,0:12:00.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(138,379)}Could be someone we know.
# Dialogue: 0,0:11:57.38,0:12:00.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(194,428)}I don't want to hear about it!
# Dialogue: 0,0:12:00.38,0:12:03.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,345)}Please get the shoes,
# Dialogue: 0,0:12:00.38,0:12:03.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,382)}I'm in a hurry.
# Dialogue: 0,0:12:00.38,0:12:03.61,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,431)}All right, all right.
# Dialogue: 0,0:12:07.22,0:12:10.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(187,357)}I'm sorry, miss,
# Dialogue: 0,0:12:07.22,0:12:10.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,394)}they're not quite ready yet.
# Dialogue: 0,0:12:07.22,0:12:10.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(185,431)}What's your address?
# Dialogue: 0,0:12:11.36,0:12:12.45,Dialogue3,Unknown,0000,0000,0000,,{\an4\pos(442,428)}224....
# Dialogue: 0,0:12:14.53,0:12:15.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(236,431)}What do you need that for?
# Dialogue: 0,0:12:15.86,0:12:19.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,357)}I thought
# Dialogue: 0,0:12:15.86,0:12:19.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(159,394)}I'd drop them over myself
# Dialogue: 0,0:12:15.86,0:12:19.13,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(158,431)}after I close my store.
# Dialogue: 0,0:12:19.80,0:12:20.93,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(432,428)}Oh. Well...
# Dialogue: 0,0:12:21.37,0:12:23.74,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(309,394)}that won't necessary.
# Dialogue: 0,0:12:21.37,0:12:23.74,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,428)}I'll come back.
# Dialogue: 0,0:12:23.81,0:12:26.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(190,382)}It's no trouble at all, miss.
# Dialogue: 0,0:12:23.81,0:12:26.00,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(254,431)}No, please, don't bother.
# Dialogue: 0,0:12:26.07,0:12:28.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,345)}Really,
# Dialogue: 0,0:12:26.07,0:12:28.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,379)}it's no trouble at all.
# Dialogue: 0,0:12:26.07,0:12:28.87,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(367,428)}Just don't bother!
# Dialogue: 0,0:12:45.66,0:12:47.72,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(245,431)\i1}âªâª{\i0}
# Dialogue: 0,0:13:08.02,0:13:09.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,431)}It's only me, Mrs. Grant.
# Dialogue: 0,0:13:09.72,0:13:10.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(105,431)}George.
# Dialogue: 0,0:13:11.12,0:13:13.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(142,394)}There's nothing
# Dialogue: 0,0:13:11.12,0:13:13.11,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(141,428)}to be scared about.
# Dialogue: 0,0:13:13.19,0:13:16.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,394)}Maybe you'll feel better
# Dialogue: 0,0:13:13.19,0:13:16.35,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(200,431)}if I give you a little light.
# Dialogue: 0,0:13:16.62,0:13:20.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(177,354)}There.
# Dialogue: 0,0:13:16.62,0:13:20.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,394)}I'll leave this door open
# Dialogue: 0,0:13:16.62,0:13:20.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(176,431)}while I put in a new bulb.
# Dialogue: 0,0:13:23.93,0:13:26.20,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(180,431)\i1}âªâª{\i0}
# Dialogue: 0,0:13:51.66,0:13:52.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,428)}Hello?
# Dialogue: 0,0:13:52.79,0:13:53.89,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(429,428)\i1}Mrs. Grant...{\i0}
# Dialogue: 0,0:13:53.96,0:13:56.09,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(308,391)\i1}this is Mr. Gibbons{\i0}
# Dialogue: 0,0:13:53.96,0:13:56.09,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(307,428)\i1}at the hardware store.{\i0}
# Dialogue: 0,0:13:56.16,0:13:57.15,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,428)}Mr. Gibbons?
# Dialogue: 0,0:13:57.23,0:13:58.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(245,431)}Oh, Mr. Gibbons!
# Dialogue: 0,0:13:58.37,0:13:59.53,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(343,428)}Yes.
# Dialogue: 0,0:13:59.60,0:14:01.83,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(280,357)\i1}I've found a man to put{\i0}
# Dialogue: 0,0:13:59.60,0:14:01.83,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(281,391)\i1}that bolt and chain on{\i0}
# Dialogue: 0,0:13:59.60,0:14:01.83,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(281,431)\i1}for you.{\i0}
# Dialogue: 0,0:14:01.90,0:14:04.46,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(271,391)\i1}But he won't be able{\i0}
# Dialogue: 0,0:14:01.90,0:14:04.46,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(272,431)\i1}to come over right away.{\i0}
# Dialogue: 0,0:14:05.07,0:14:07.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,394)}That's all right.
# Dialogue: 0,0:14:05.07,0:14:07.20,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(242,428)}Whenever he can.
# Dialogue: 0,0:14:07.28,0:14:08.40,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,428)}Whenever....
# Dialogue: 0,0:14:08.48,0:14:11.21,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(204,391)\i1}Fine. I'll tell him to make it{\i0}
# Dialogue: 0,0:14:08.48,0:14:11.21,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(204,431)\i1}as soon as possible.{\i0}
# Dialogue: 0,0:14:11.28,0:14:13.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,394)}Thank you.
# Dialogue: 0,0:14:11.28,0:14:13.98,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(175,431)}Thank you, I'm very grateful.
# Dialogue: 0,0:14:14.05,0:14:16.18,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(386,345)\i1}That's all right.{\i0}
# Dialogue: 0,0:14:14.05,0:14:16.18,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(385,382)\i1}Goodbye, now.{\i0}
# Dialogue: 0,0:14:14.05,0:14:16.18,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(326,431)}Bye.
# Dialogue: 0,0:14:22.76,0:14:23.78,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(246,428)}Hi.
# Dialogue: 0,0:14:25.49,0:14:27.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,431)}I was waiting for you.
# ...
# Dialogue: 0,0:19:30.90,0:19:33.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(139,394)}Sure, Mrs. Grant.
# Dialogue: 0,0:19:30.90,0:19:33.42,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(140,431)}I'd be glad to.
# Dialogue: 0,0:19:34.67,0:19:38.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,394)}You, too!
# Dialogue: 0,0:19:34.67,0:19:38.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,428)}Just like all the others.
# Dialogue: 0,0:19:39.81,0:19:43.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(235,382)}What do you mean by that?
# Dialogue: 0,0:19:39.81,0:19:43.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,431)}Very innocent, aren't you?
# Dialogue: 0,0:19:43.61,0:19:45.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(149,394)}You ought to be
# Dialogue: 0,0:19:43.61,0:19:45.41,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(150,431)}ashamed of yourself.
# Dialogue: 0,0:19:45.48,0:19:47.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(167,394)}The minute your husband's back
# Dialogue: 0,0:19:45.48,0:19:47.31,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(168,428)}is turned...
# Dialogue: 0,0:19:47.38,0:19:49.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(149,394)}out trying to make
# Dialogue: 0,0:19:47.38,0:19:49.01,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(149,431)}a living for you.
# Dialogue: 0,0:19:49.08,0:19:51.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,342)}You don't know
# Dialogue: 0,0:19:49.08,0:19:51.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(243,382)}what you're talking about.
# Dialogue: 0,0:19:49.08,0:19:51.85,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,428)}Don't I?
# Dialogue: 0,0:19:51.92,0:19:54.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,394)}I've got eyes in my head,
# Dialogue: 0,0:19:51.92,0:19:54.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(163,428)}haven't I?
# Dialogue: 0,0:19:54.92,0:19:57.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,394)}But I'd watch my step
# Dialogue: 0,0:19:54.92,0:19:57.95,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(165,431)}if I were you, milady.
# Dialogue: 0,0:19:58.03,0:20:01.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,394)}Women like you always get
# Dialogue: 0,0:19:58.03,0:20:01.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(169,431)}what they deserve in the end.
# Dialogue: 0,0:20:02.50,0:20:05.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(362,382)}You're disgusting!
# Dialogue: 0,0:20:02.50,0:20:05.80,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(166,431)}To the likes of you, maybe.
# Dialogue: 0,0:20:07.74,0:20:10.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(145,357)}But just remember
# Dialogue: 0,0:20:07.74,0:20:10.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(143,394)}what happened
# Dialogue: 0,0:20:07.74,0:20:10.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(143,428)}to those other two.
# Dialogue: 0,0:20:24.55,0:20:25.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(270,428)}Who is it?
# Dialogue: 0,0:20:26.52,0:20:29.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,431)}It's me, Mrs. Grant. George.
# Dialogue: 0,0:20:30.36,0:20:32.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(161,431)}I got your husband's shoes.
# Dialogue: 0,0:20:35.20,0:20:37.83,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(265,431)}Oh, yes, I forgot.
# Dialogue: 0,0:20:45.27,0:20:48.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(241,394)}Would you just leave them
# Dialogue: 0,0:20:45.27,0:20:48.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(242,431)}outside the door, please?
# Dialogue: 0,0:20:48.34,0:20:51.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(152,394)}Mrs. Grant, somebody's
# Dialogue: 0,0:20:48.34,0:20:51.24,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(152,428)}liable to steal them.
# Dialogue: 0,0:20:51.51,0:20:52.57,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(355,431)}Well, that's all....
# Dialogue: 0,0:20:52.65,0:20:53.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(421,428)}Let them.
# Dialogue: 0,0:20:54.28,0:20:55.44,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(135,431)}All right.
# Dialogue: 0,0:21:24.85,0:21:26.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(339,352)}Yes?
# Dialogue: 0,0:21:24.85,0:21:26.97,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(405,428)\i1}Mrs. Grant?{\i0}
# Dialogue: 0,0:21:27.58,0:21:28.71,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(343,428)}Yes.
# Dialogue: 0,0:21:28.78,0:21:30.41,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(246,391)\i1}Mr. Gibbons{\i0}
# Dialogue: 0,0:21:28.78,0:21:30.41,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(247,428)\i1}from the hardware store...{\i0}
# Dialogue: 0,0:21:30.48,0:21:32.72,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(310,391)\i1}sent me around{\i0}
# Dialogue: 0,0:21:30.48,0:21:32.72,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(312,431)\i1}to put on a new lock.{\i0}
# Dialogue: 0,0:21:32.79,0:21:34.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(332,428)}Oh.
# Dialogue: 0,0:21:34.82,0:21:36.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,394)}I thought
# Dialogue: 0,0:21:34.82,0:21:36.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(220,431)}you'd never get here!
# Dialogue: 0,0:21:36.86,0:21:38.69,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(281,394)\i1}Well, we're pretty busy,{\i0}
# Dialogue: 0,0:21:36.86,0:21:38.69,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(279,428)\i1}ma'am.{\i0}
# Dialogue: 0,0:21:38.76,0:21:42.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,357)}Yes, yes, I know you are.
# Dialogue: 0,0:21:38.76,0:21:42.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(199,394)}I'm just so grateful
# Dialogue: 0,0:21:38.76,0:21:42.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(197,431)}that you're here.
# Dialogue: 0,0:21:42.86,0:21:44.33,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(263,431)}Apartment 1A.
# Dialogue: 0,0:21:58.68,0:21:59.70,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(331,428)}Hello?
# Dialogue: 0,0:22:00.28,0:22:01.51,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(271,431)}Hello, honey.
# Dialogue: 0,0:22:01.82,0:22:04.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(234,394)}Oh, Steve, I'm so glad
# Dialogue: 0,0:22:01.82,0:22:04.79,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(233,431)}to hear your voice.
# Dialogue: 0,0:22:05.42,0:22:08.12,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(431,382)\i1}You all right?{\i0}
# Dialogue: 0,0:22:05.42,0:22:08.12,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(226,431)}Yeah, yeah, I'm fine.
# Dialogue: 0,0:22:08.62,0:22:11.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(240,382)}You sound funny.
# Dialogue: 0,0:22:08.62,0:22:11.96,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,431)}No. No, I'm all right now.
# Dialogue: 0,0:22:12.36,0:22:14.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(198,391)}I don't know what's been
# Dialogue: 0,0:22:12.36,0:22:14.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(196,428)}the matter with me.
# Dialogue: 0,0:22:14.33,0:22:17.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,394)}I'm scared out of my wits,
# Dialogue: 0,0:22:14.33,0:22:17.26,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(247,431)}imagining things.
# Dialogue: 0,0:22:18.03,0:22:21.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(170,355)}Talk about being neurotic.
# Dialogue: 0,0:22:18.03,0:22:21.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(339,394)}No, honey,
# Dialogue: 0,0:22:18.03,0:22:21.09,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(337,431)}you're not neurotic.
# Dialogue: 0,0:22:21.17,0:22:23.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(268,394)}You just haven't been
# Dialogue: 0,0:22:21.17,0:22:23.73,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(269,431)}feeling well, that's all.
# Dialogue: 0,0:22:23.80,0:22:26.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,394)}I guess I didn't help things
# Dialogue: 0,0:22:23.80,0:22:26.60,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(222,428)}much this afternoon.
# Dialogue: 0,0:22:26.77,0:22:28.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(367,382)}I'm sorry.
# Dialogue: 0,0:22:26.77,0:22:28.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,431)}That's all right, honey.
# Dialogue: 0,0:22:29.64,0:22:32.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,394)}It's this heat. It's enough
# Dialogue: 0,0:22:29.64,0:22:32.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(178,431)}to drive anybody crazy.
# Dialogue: 0,0:22:32.45,0:22:34.68,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(455,382)\i1}Forgive me?{\i0}
# Dialogue: 0,0:22:32.45,0:22:34.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(260,428)}Of course I do.
# Dialogue: 0,0:22:35.12,0:22:36.78,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(376,428)\i1}Is Ed still there?{\i0}
# Dialogue: 0,0:22:37.48,0:22:40.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(212,431)}Ed. Did you send him?
# Dialogue: 0,0:22:40.42,0:22:44.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,345)}Well, sure, honey,
# Dialogue: 0,0:22:40.42,0:22:44.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(323,382)}to keep you company.
# Dialogue: 0,0:22:40.42,0:22:44.32,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(146,431)}Keep me company, huh?
# Dialogue: 0,0:22:45.06,0:22:48.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,345)}Well,
# Dialogue: 0,0:22:45.06,0:22:48.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(232,382)}I finally got rid of him.
# Dialogue: 0,0:22:45.06,0:22:48.19,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(248,431)}I wished you hadn't have.
# Dialogue: 0,0:22:48.33,0:22:50.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(339,394)}Look, honey,
# Dialogue: 0,0:22:48.33,0:22:50.30,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(337,431)}will you be careful?
# Dialogue: 0,0:22:50.36,0:22:54.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,357)}And promise me you won't let
# Dialogue: 0,0:22:50.36,0:22:54.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(203,394)}anybody in the apartment
# Dialogue: 0,0:22:50.36,0:22:54.39,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(202,431)}till I get home, all right?
# Dialogue: 0,0:22:54.47,0:22:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(225,394)}All right.
# Dialogue: 0,0:22:54.47,0:22:56.49,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,431)}Don't worry, I won't.
# Dialogue: 0,0:22:57.84,0:23:01.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(190,357)}Anyway, it's all right now.
# Dialogue: 0,0:22:57.84,0:23:01.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,391)}The locksmith's here
# Dialogue: 0,0:22:57.84,0:23:01.43,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(190,431)}to put the chain on.
# Dialogue: 0,0:23:01.51,0:23:03.64,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(528,379)\i1}Ellen--{\i0}
# Dialogue: 0,0:23:01.51,0:23:03.64,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(293,431)}Wait a minute, Steve.
# Dialogue: 0,0:23:04.78,0:23:05.87,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(496,428)\i1}Ellen!{\i0}
# Dialogue: 0,0:23:06.28,0:23:09.25,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(438,355)\i1}Hello, Ellen!{\i0}
# Dialogue: 0,0:23:06.28,0:23:09.25,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(144,431)}Come on in, will you?
# Dialogue: 0,0:23:09.32,0:23:10.75,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,431)}I want it put right there.
# Dialogue: 0,0:23:10.82,0:23:11.88,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(249,431)}All right, ma'am.
# Dialogue: 0,0:23:11.95,0:23:14.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,354)}Excuse me a minute.
# Dialogue: 0,0:23:11.95,0:23:14.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(192,394)}I'm talking to my husband
# Dialogue: 0,0:23:11.95,0:23:14.55,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(191,431)}on the phone.
# Dialogue: 0,0:23:14.62,0:23:17.89,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(409,379)\i1}Ellen! Ellen....{\i0}
# Dialogue: 0,0:23:14.62,0:23:17.89,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(311,431)}Hello, Steve.
# Dialogue: 0,0:23:18.16,0:23:20.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(274,394)}Honey, who did you just
# Dialogue: 0,0:23:18.16,0:23:20.72,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(274,431)}let in the apartment?
# Dialogue: 0,0:23:21.00,0:23:23.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(173,357)}The locksmith,
# Dialogue: 0,0:23:21.00,0:23:23.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(172,394)}to put the chain on the door.
# Dialogue: 0,0:23:21.00,0:23:23.97,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(174,431)}He finally got here.
# Dialogue: 0,0:23:24.03,0:23:27.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,354)}A locksmith?
# Dialogue: 0,0:23:24.03,0:23:27.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(310,394)}Ellen, didn't you hear
# Dialogue: 0,0:23:24.03,0:23:27.16,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(308,428)}the radio broadcast?
# Dialogue: 0,0:23:27.57,0:23:29.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(176,431)}What are you talking about?
# Dialogue: 0,0:23:29.74,0:23:33.30,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(259,357)\i1}It was just on the radio.{\i0}
# Dialogue: 0,0:23:29.74,0:23:33.30,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(261,394)\i1}The police are looking{\i0}
# Dialogue: 0,0:23:29.74,0:23:33.30,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(260,428)\i1}for a locksmith!{\i0}
# Dialogue: 0,0:23:33.41,0:23:36.47,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(181,394)\i1}Honey, they think he's the one{\i0}
# Dialogue: 0,0:23:33.41,0:23:36.47,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(182,428)\i1}that killed those women!{\i0}
# Dialogue: 0,0:23:38.18,0:23:39.84,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(438,428)\i1}Ellen! Ellen!{\i0}
# Dialogue: 0,0:23:40.51,0:23:42.04,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(313,431)\i1}Ellen, are you there?{\i0}
# Dialogue: 0,0:23:43.75,0:23:45.22,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(306,431)}Oh, Steve!
# Dialogue: 0,0:23:46.02,0:23:47.68,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(386,428)}Steve!
# Dialogue: 0,0:23:56.53,0:23:59.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(226,394)}And so, once again,
# Dialogue: 0,0:23:56.53,0:23:59.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(227,431)}The Creeper commits...
# Dialogue: 0,0:23:59.93,0:24:03.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(223,391)}the most heinous crime
# Dialogue: 0,0:23:59.93,0:24:03.77,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(224,431)}a woman can imagine:
# Dialogue: 0,0:24:03.84,0:24:07.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,357)}He takes the telephone
# Dialogue: 0,0:24:03.84,0:24:07.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(229,394)}away from her
# Dialogue: 0,0:24:03.84,0:24:07.37,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(230,428)}in the middle of a call.
# Dialogue: 0,0:24:08.24,0:24:11.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(240,357)}Obviously,
# Dialogue: 0,0:24:08.24,0:24:11.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,391)}this sadistic criminal
# Dialogue: 0,0:24:08.24,0:24:11.27,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(239,431)}will stop at nothing.
# Dialogue: 0,0:24:12.11,0:24:15.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(182,394)}For the record, The Creeper
# Dialogue: 0,0:24:12.11,0:24:15.14,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(180,431)}was subsequently caught...
# Dialogue: 0,0:24:15.38,0:24:20.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,357)}and is now repairing locks
# Dialogue: 0,0:24:15.38,0:24:20.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(205,394)}at one of our leading
# Dialogue: 0,0:24:15.38,0:24:20.29,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(206,431)}penal institutions.
# Dialogue: 0,0:24:21.19,0:24:23.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,394)}If you liked our story,
# Dialogue: 0,0:24:21.19,0:24:23.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(219,431)}please write in.
# Dialogue: 0,0:24:24.59,0:24:27.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(217,357)}Perhaps we can give you
# Dialogue: 0,0:24:24.59,0:24:27.86,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(216,394)}a sequel to {\i1}The Creeper,{\i0}
# Dialogue: 0,0:24:24.59,0:24:27.86,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(216,428)}called:
# Dialogue: 0,0:24:28.00,0:24:29.40,Dialogue4,Unknown,0000,0000,0000,,{\an4\pos(293,428)\i1}The Toddler.{\i0}
# Dialogue: 0,0:24:29.66,0:24:30.82,Dialogue2,Unknown,0000,0000,0000,,{\an4\pos(278,431)}Good night.

# %% [markdown]
# ## **Step 6 - Applying the above Function on the Entire Data**

# %%
count = 0

def decode_method(binary_data):
    global count
    # Decompress the binary data using the zipfile module
    # print(count, end=" ")
    count += 1
    with io.BytesIO(binary_data) as f:
        with zipfile.ZipFile(f, 'r') as zip_file:
            # Assuming there's only one file in the ZIP archive
            subtitle_content = zip_file.read(zip_file.namelist()[0])
    
    # Now 'subtitle_content' should contain the extracted subtitle content
    return subtitle_content.decode('latin-1')  # Assuming the content is UTF-8 encoded text

# %%
df_30_percent_data['file_content'] = df_30_percent_data['content'].apply(decode_method)

df_30_percent_data.head()
# Out:
#            num                                               name  \
# 68884  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 72341  9478254                             red.eye.(2005).eng.1cd
# 44918  9367553                                  10.(2022).eng.1cd
# 5016   9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 21135  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
#
#                                                  content  \
# 68884  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf5d\x9aV...
# 72341  b'PK\x03\x04\x14\x00\x00\x00\x08\x00*q\x9aV\xb...
# 44918  b'PK\x03\x04\x14\x00\x00\x00\x08\x00|\x0e\x9aV...
# 5016   b'PK\x03\x04\x14\x00\x00\x00\x08\x00d\x8d\x99V...
# 21135  b'PK\x03\x04\x14\x00\x00\x00\x08\x00*\x9d\x99V...
#
#                                             file_content
# 68884  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 72341  ï»¿1\r\n00:00:33,909 --> 00:00:37,204\r\n[jet ...
# 44918  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 5016   ï»¿1\r\n00:00:02,102 --> 00:00:03,468\r\nFRANC...
# 21135  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...

# %%
df_30_percent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24749 entries, 68884 to 23396
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num           24749 non-null  int64
#  1   name          24749 non-null  object
#  2   content       24749 non-null  object
#  3   file_content  24749 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 966.8+ KB

# %%
df_30_percent_data.tail()
# Out:
#            num                                               name  \
# 20877  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 75381  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 30008  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 8170   9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 23396  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                  content  \
# 20877  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xcd\x9c\x...
# 75381  b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf9\x82\x...
# 30008  b'PK\x03\x04\x14\x00\x00\x00\x08\x00,\xab\x99V...
# 8170   b'PK\x03\x04\x14\x00\x00\x00\x08\x00H\x90\x99V...
# 23396  b'PK\x03\x04\x14\x00\x00\x00\x08\x00G\x9f\x99V...
#
#                                             file_content
# 20877  ï»¿1\r\n00:00:02,194 --> 00:00:05,218\r\n<i>Pr...
# 75381  1\r\n00:01:01,006 --> 00:01:02,423\r\nI think ...
# 30008  ï»¿1\r\n00:00:00,801 --> 00:00:03,673\r\n[dram...
# 8170   ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
# 23396  1\r\n00:00:08,132 --> 00:00:11,136\r\n<i>"Any ...

# %% [markdown]
# ### DROPPING THE "CONTENT" COLUMN

# %%
df_30_percent_data =  df_30_percent_data.drop(columns='content')

# %%
df_30_percent_data.head()
# Out:
#            num                                               name  \
# 68884  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 72341  9478254                             red.eye.(2005).eng.1cd
# 44918  9367553                                  10.(2022).eng.1cd
# 5016   9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 21135  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
#
#                                             file_content
# 68884  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 72341  ï»¿1\r\n00:00:33,909 --> 00:00:37,204\r\n[jet ...
# 44918  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 5016   ï»¿1\r\n00:00:02,102 --> 00:00:03,468\r\nFRANC...
# 21135  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...

# %% [markdown]
# ### RENAMING THE COLUMN NAMES

# %%
df_30_percent_data.rename(columns={"num":"id",
             "name":"Movies/Series",
             "file_content":"subtitles"},inplace=True)

# %%
df_30_percent_data.head()
# Out:
#             id                                      Movies/Series  \
# 68884  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 72341  9478254                             red.eye.(2005).eng.1cd
# 44918  9367553                                  10.(2022).eng.1cd
# 5016   9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 21135  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
#
#                                                subtitles
# 68884  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 72341  ï»¿1\r\n00:00:33,909 --> 00:00:37,204\r\n[jet ...
# 44918  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 5016   ï»¿1\r\n00:00:02,102 --> 00:00:03,468\r\nFRANC...
# 21135  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 68884  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 72341  9478254                             red.eye.(2005).eng.1cd
# 44918  9367553                                  10.(2022).eng.1cd
# 5016   9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 21135  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 20877  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 75381  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 30008  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 8170   9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 23396  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles
# 68884  ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 72341  ï»¿1\r\n00:00:33,909 --> 00:00:37,204\r\n[jet ...
# 44918  1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 5016   ï»¿1\r\n00:00:02,102 --> 00:00:03,468\r\nFRANC...
# 21135  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# ...                                                  ...
# 20877  ï»¿1\r\n00:00:02,194 --> 00:00:05,218\r\n<i>Pr...
# 75381  1\r\n00:01:01,006 --> 00:01:02,423\r\nI think ...
# 30008  ï»¿1\r\n00:00:00,801 --> 00:00:03,673\r\n[dram...
# 8170   ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
# 23396  1\r\n00:00:08,132 --> 00:00:11,136\r\n<i>"Any ...
#
# [24749 rows x 3 columns]

# %%
# Reset Index

# %%
# Reset index for the DataFrame
df_30_percent_data = df_30_percent_data.reset_index(drop=True)
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles
# 0      ï»¿[Script Info]\r\nTitle: Default file\r\nScr...
# 1      ï»¿1\r\n00:00:33,909 --> 00:00:37,204\r\n[jet ...
# 2      1\r\n00:00:06,000 --> 00:00:12,074\r\nAdvertis...
# 3      ï»¿1\r\n00:00:02,102 --> 00:00:03,468\r\nFRANC...
# 4      ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nAdver...
# ...                                                  ...
# 24744  ï»¿1\r\n00:00:02,194 --> 00:00:05,218\r\n<i>Pr...
# 24745  1\r\n00:01:01,006 --> 00:01:02,423\r\nI think ...
# 24746  ï»¿1\r\n00:00:00,801 --> 00:00:03,673\r\n[dram...
# 24747  ï»¿1\r\n00:00:06,000 --> 00:00:12,074\r\nUse t...
# 24748  1\r\n00:00:08,132 --> 00:00:11,136\r\n<i>"Any ...
#
# [24749 rows x 3 columns]

# %% [markdown]
# #  Preprocessing of data

# %%
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# **`removing special characters`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].str.replace(r'[^a-zA-Z\s]', '')
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_50656\1816806813.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['subtitles'] = df['subtitles'].str.replace(r'[^a-zA-Z\s]', '')

# %% [markdown]
# **`removing non ASCII characters`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].str.replace(r'[^\x00-\x7F]+', '')
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_50656\640278417.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['subtitles'] = df['subtitles'].str.replace(r'[^\x00-\x7F]+', '')

# %% [markdown]
# **`removing time-stamp`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].str.replace(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '')
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_50656\3909944480.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['subtitles'] = df['subtitles'].str.replace(r'\d{2}:\d{2}:\d{2}\d{3} --> \d{2}:\d{2}:\d{2},\d{3}', '')

# %% [markdown]
# **`converting to lowercase`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].str.lower()

# %% [markdown]
# **`removing extra spaces`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].str.replace(r'\s+', ' ' )
# Out:
# C:\Users\rjsek\AppData\Local\Temp\ipykernel_50656\2287085623.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['subtitles'] = df['subtitles'].str.replace(r'\s+', ' ' )

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles
# 0      script info title default file scripttype v wr...
# 1       jet engine revving anman lets go anwoman tayl...
# 2       advertise your product or brand here contact ...
# 3       francis ipreviously oni reign her majesty mar...
# 4       advertise your product or brand here contact ...
# ...                                                  ...
# 24744   ipreviously oni font colorfffthe real housewi...
# 24745   i think thats enough for today good now pleas...
# 24746   dramatic orchestral music plays indistinct ch...
# 24747   use the free code joinnow at wwwplayshipseu s...
# 24748   iany guy playingi watch any video online with...
#
# [24749 rows x 3 columns]

# %%
# !pip install swifter
# Out:
# Requirement already satisfied: swifter in c:\users\rjsek\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\rjsek\anaconda3\lib\site-packages (from swifter) (2022.7.0)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\rjsek\anaconda3\lib\site-packages (from swifter) (4.66.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\rjsek\anaconda3\lib\site-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\rjsek\anaconda3\lib\site-packages (from swifter) (5.9.0)
# Requirement already satisfied: partd>=0.3.10 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (23.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2024.3.1)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\rjsek\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.23.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rjsek\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rjsek\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: colorama in c:\users\rjsek\anaconda3\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.6)
# Requirement already satisfied: locket in c:\users\rjsek\anaconda3\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\rjsek\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->swifter) (1.16.0)

# %%
import swifter

# %% [markdown]
# **`Tokenization step`**

# %%
df_30_percent_data['subtitles'] = df_30_percent_data['subtitles'].swifter.apply(lambda x: word_tokenize(x))
# Out:
# Pandas Apply:   0%|          | 0/24749 [00:00<?, ?it/s]

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles
# 0      [script, info, title, default, file, scripttyp...
# 1      [jet, engine, revving, anman, lets, go, anwoma...
# 2      [advertise, your, product, or, brand, here, co...
# 3      [francis, ipreviously, oni, reign, her, majest...
# 4      [advertise, your, product, or, brand, here, co...
# ...                                                  ...
# 24744  [ipreviously, oni, font, colorfffthe, real, ho...
# 24745  [i, think, thats, enough, for, today, good, no...
# 24746  [dramatic, orchestral, music, plays, indistinc...
# 24747  [use, the, free, code, joinnow, at, wwwplayshi...
# 24748  [iany, guy, playingi, watch, any, video, onlin...
#
# [24749 rows x 3 columns]

# %% [markdown]
# ### BERT based “SentenceTransformers” to generate embeddings which encode semantic information.
# ### This can help us build a Semantic Search Engine.

# %%
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\rjsek\anaconda3\lib\site-packages (2.6.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (1.12.1)
# Requirement already satisfied: scipy in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: scikit-learn in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (1.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (4.39.3)
# Requirement already satisfied: numpy in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: Pillow in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: tqdm in c:\users\rjsek\anaconda3\lib\site-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.3.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0)
# Requirement already satisfied: requests in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: filelock in c:\users\rjsek\anaconda3\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.9.0)
# Requirement already satisfied: colorama in c:\users\rjsek\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\rjsek\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\rjsek\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\rjsek\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rjsek\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\rjsek\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rjsek\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rjsek\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rjsek\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rjsek\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.4)

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd

# Load a pre-trained BERT model (using CPU)
model = SentenceTransformer('paraphrase-MiniLM-L3-v2', device='cpu')

# Function to encode text using BERT
def encode_text(text):
    # Encode the text into an embedding
    try:
        embedding = model.encode(text)
        return embedding
    except Exception as e:
        print(f"Error encoding text: {e}")
        return None

# Convert list of words into a single string sentence
df_30_percent_data['subtitles_sentence'] = df_30_percent_data['subtitles'].apply(lambda x: ' '.join(x))

# Apply BERT vectorization to the 'subtitles_sentence' column
df_30_percent_data['bert_embedding'] = df_30_percent_data['subtitles_sentence'].apply(encode_text)

# Display the updated DataFrame
print(df_30_percent_data.head())
# Out:
#         id                                      Movies/Series  \
# 0  9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1  9478254                             red.eye.(2005).eng.1cd
# 2  9367553                                  10.(2022).eng.1cd
# 3  9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4  9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
#
#                                            subtitles  \
# 0  [script, info, title, default, file, scripttyp...
# 1  [jet, engine, revving, anman, lets, go, anwoma...
# 2  [advertise, your, product, or, brand, here, co...
# 3  [francis, ipreviously, oni, reign, her, majest...
# 4  [advertise, your, product, or, brand, here, co...
#
#                                   subtitles_sentence  \
# 0  script info title default file scripttype v wr...
# 1  jet engine revving anman lets go anwoman taylo...
# 2  advertise your product or brand here contact w...
# 3  francis ipreviously oni reign her majesty mari...
# 4  advertise your product or brand here contact w...
#
#                                       bert_embedding
# 0  [0.019202188, -0.10135785, 0.05124608, 0.07146...
# 1  [0.06227134, -0.15009682, 0.23519003, -0.04188...
# 2  [-0.08674303, 0.113942094, 0.07312267, -0.0547...
# 3  [0.057274677, 0.18626337, -0.005120895, -0.154...
# 4  [-0.04211163, -0.040654175, -0.010191287, -0.1...

# %%
df_30_percent_data['bert_embedding']
# Out:
# 0        [0.019202188, -0.10135785, 0.05124608, 0.07146...
# 1        [0.06227134, -0.15009682, 0.23519003, -0.04188...
# 2        [-0.08674303, 0.113942094, 0.07312267, -0.0547...
# 3        [0.057274677, 0.18626337, -0.005120895, -0.154...
# 4        [-0.04211163, -0.040654175, -0.010191287, -0.1...
#                                ...
# 24744    [0.14130643, -0.16698056, 0.33102593, 0.074704...
# 24745    [0.111511536, -0.026505634, 0.20732762, -0.159...
# 24746    [-0.11328379, -0.06661039, 0.11664734, 0.11008...
# 24747    [0.033705004, 0.0017321683, 0.049905933, -0.02...
# 24748    [-0.024892502, -0.14684628, 0.045202546, 0.053...
# Name: bert_embedding, Length: 24749, dtype: object

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles  \
# 0      [script, info, title, default, file, scripttyp...
# 1      [jet, engine, revving, anman, lets, go, anwoma...
# 2      [advertise, your, product, or, brand, here, co...
# 3      [francis, ipreviously, oni, reign, her, majest...
# 4      [advertise, your, product, or, brand, here, co...
# ...                                                  ...
# 24744  [ipreviously, oni, font, colorfffthe, real, ho...
# 24745  [i, think, thats, enough, for, today, good, no...
# 24746  [dramatic, orchestral, music, plays, indistinc...
# 24747  [use, the, free, code, joinnow, at, wwwplayshi...
# 24748  [iany, guy, playingi, watch, any, video, onlin...
#
#                                       subtitles_sentence  \
# 0      script info title default file scripttype v wr...
# 1      jet engine revving anman lets go anwoman taylo...
# 2      advertise your product or brand here contact w...
# 3      francis ipreviously oni reign her majesty mari...
# 4      advertise your product or brand here contact w...
# ...                                                  ...
# 24744  ipreviously oni font colorfffthe real housewiv...
# 24745  i think thats enough for today good now please...
# 24746  dramatic orchestral music plays indistinct cha...
# 24747  use the free code joinnow at wwwplayshipseu si...
# 24748  iany guy playingi watch any video online with ...
#
#                                           bert_embedding
# 0      [0.019202188, -0.10135785, 0.05124608, 0.07146...
# 1      [0.06227134, -0.15009682, 0.23519003, -0.04188...
# 2      [-0.08674303, 0.113942094, 0.07312267, -0.0547...
# 3      [0.057274677, 0.18626337, -0.005120895, -0.154...
# 4      [-0.04211163, -0.040654175, -0.010191287, -0.1...
# ...                                                  ...
# 24744  [0.14130643, -0.16698056, 0.33102593, 0.074704...
# 24745  [0.111511536, -0.026505634, 0.20732762, -0.159...
# 24746  [-0.11328379, -0.06661039, 0.11664734, 0.11008...
# 24747  [0.033705004, 0.0017321683, 0.049905933, -0.02...
# 24748  [-0.024892502, -0.14684628, 0.045202546, 0.053...
#
# [24749 rows x 5 columns]

# %% [markdown]
# ### DOCUMNET CHUNKER

# %%
# Creating  a function that takes a large document as input and divides it into smaller chunks 
# with an overlap to maintain context continuity.

# %%
# Define semantic chunking function
def semantic_chunking(embeddings, chunk_size=1000, overlap=50):
    chunks = []
    if isinstance(embeddings, np.ndarray) and len(embeddings.shape) == 1:
        # Single embedding (numpy array or float)
        embeddings = [embeddings]  # Convert to a list for consistency
    for embedding in embeddings:
        if isinstance(embedding, np.ndarray):
            embedding = ' '.join(map(str, embedding))  # Convert array to string
        else:
            embedding = str(embedding)  # Convert float to string
        for start in range(0, len(embedding), chunk_size - overlap):
            chunk = embedding[start:start + chunk_size]
            chunks.append(chunk)
    return chunks

# Apply semantic chunking to the 'bert_embedding' column
df_30_percent_data['bert_embedding_chunks'] = df_30_percent_data['bert_embedding'].apply(semantic_chunking)

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles  \
# 0      [script, info, title, default, file, scripttyp...
# 1      [jet, engine, revving, anman, lets, go, anwoma...
# 2      [advertise, your, product, or, brand, here, co...
# 3      [francis, ipreviously, oni, reign, her, majest...
# 4      [advertise, your, product, or, brand, here, co...
# ...                                                  ...
# 24744  [ipreviously, oni, font, colorfffthe, real, ho...
# 24745  [i, think, thats, enough, for, today, good, no...
# 24746  [dramatic, orchestral, music, plays, indistinc...
# 24747  [use, the, free, code, joinnow, at, wwwplayshi...
# 24748  [iany, guy, playingi, watch, any, video, onlin...
#
#                                       subtitles_sentence  \
# 0      script info title default file scripttype v wr...
# 1      jet engine revving anman lets go anwoman taylo...
# 2      advertise your product or brand here contact w...
# 3      francis ipreviously oni reign her majesty mari...
# 4      advertise your product or brand here contact w...
# ...                                                  ...
# 24744  ipreviously oni font colorfffthe real housewiv...
# 24745  i think thats enough for today good now please...
# 24746  dramatic orchestral music plays indistinct cha...
# 24747  use the free code joinnow at wwwplayshipseu si...
# 24748  iany guy playingi watch any video online with ...
#
#                                           bert_embedding  \
# 0      [0.019202188, -0.10135785, 0.05124608, 0.07146...
# 1      [0.06227134, -0.15009682, 0.23519003, -0.04188...
# 2      [-0.08674303, 0.113942094, 0.07312267, -0.0547...
# 3      [0.057274677, 0.18626337, -0.005120895, -0.154...
# 4      [-0.04211163, -0.040654175, -0.010191287, -0.1...
# ...                                                  ...
# 24744  [0.14130643, -0.16698056, 0.33102593, 0.074704...
# 24745  [0.111511536, -0.026505634, 0.20732762, -0.159...
# 24746  [-0.11328379, -0.06661039, 0.11664734, 0.11008...
# 24747  [0.033705004, 0.0017321683, 0.049905933, -0.02...
# 24748  [-0.024892502, -0.14684628, 0.045202546, 0.053...
#
#                                    bert_embedding_chunks
# 0      [0.019202188 -0.10135785 0.05124608 0.07146899...
# 1      [0.06227134 -0.15009682 0.23519003 -0.04188167...
# 2      [-0.08674303 0.113942094 0.07312267 -0.0547033...
# 3      [0.057274677 0.18626337 -0.005120895 -0.154800...
# 4      [-0.04211163 -0.040654175 -0.010191287 -0.1076...
# ...                                                  ...
# 24744  [0.14130643 -0.16698056 0.33102593 0.0747046 -...
# 24745  [0.111511536 -0.026505634 0.20732762 -0.159436...
# 24746  [-0.11328379 -0.06661039 0.11664734 0.11008331...
# 24747  [0.033705004 0.0017321683 0.049905933 -0.02711...
# 24748  [-0.024892502 -0.14684628 0.045202546 0.053789...
#
# [24749 rows x 6 columns]

# %%
# Saving the data

# %%
# Assuming df_30_percent_data is your DataFrame
df_30_percent_data.to_csv('df_30_percent_data.csv', index=False, escapechar='\\')

# Providing a download link
from IPython.display import FileLink
FileLink('df_30_percent_data.csv')

# %% [markdown]
# ## SAVING THE df_30_percent_data

# %%
import joblib

# %%
## Specify the file path where you want to save the DataFrame
file_path='C:/Users/rjsek/OneDrive/Desktop/Search Engine Project'

# %%
#saving the dataframe using joblib
joblib.dump(df_30_percent_data,file_path)

# %%
import joblib

# Update the file path to a location with write permissions
file_path = 'C:/Users/rjsek/Desktop/search_engine_data.pkl'  # Replace with your desired path

# Save the DataFrame
joblib.dump(df_30_percent_data, file_path)

# %% [markdown]
# ## Preparing indexes

# %%
def indexer(item):
    index = []
    temp_df_30_percent_data = df_30_percent_data[df_30_percent_data['id'] == item]
    if not temp_df_30_percent_data.empty:
        temp_index = temp_df_30_percent_data.index[0]
        print("Temp index:", temp_index)
        bert_chunks_length = len(df_30_percent_data["bert_embedding_chunks"])
        print("Shape of bert_embedding_chunks DataFrame:", df_30_percent_data["bert_embedding_chunks"].shape)
        if temp_index < bert_chunks_length:
            for j in range(len(df_30_percent_data["bert_embedding_chunks"].iloc[temp_index])):
                index.append(str(item) + "-" + str(j))
            return index
        else:
            print("Index out of bounds for item:", item)
    else:
        print("Item not found in DataFrame:", item)
    return []

# %%
df_30_percent_data['num_list'] = df_30_percent_data['id'].apply(indexer)
# Out:
# Temp index: 0
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 1
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 2
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 3
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 4
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 5
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 6
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 7
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 8
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 9
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 10
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 11
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 12
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 13
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 14
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 15
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 16
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 17
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 18
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 19
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 20
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 21
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 22
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 23
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 25
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 26
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 27
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 28
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 29
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 30
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 31
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 32
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 33
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 34
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 35
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 36
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 37
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 38
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 39
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 40
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 41
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 42
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 43
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 44
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 45
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 46
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 47
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 48
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 49
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 50
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 51
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 52
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 53
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 54
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 55
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 56
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 57
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 58
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 59
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 60
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 61
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 62
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 63
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 64
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 65
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 66
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 67
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 68
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 69
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 70
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 71
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 72
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 73
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 74
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 75
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 76
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 77
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 78
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 79
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 80
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 81
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 82
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 83
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 84
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 85
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 86
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 87
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 88
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 89
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 90
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 91
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 92
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 93
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 94
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 95
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 96
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 97
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 98
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 99
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 100
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 101
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 102
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 103
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 104
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 105
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 106
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 107
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 108
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 109
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 110
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 111
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 112
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 113
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 114
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 115
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 116
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 117
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 118
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 119
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 120
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 121
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 122
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 123
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 124
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 125
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 126
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 127
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 128
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 129
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 130
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 131
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 132
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 133
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 134
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 135
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 136
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 137
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 138
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 139
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 140
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 141
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 142
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 143
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 144
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 145
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 146
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 147
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 148
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 149
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 150
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 151
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 152
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 153
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 154
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 155
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 156
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 157
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 158
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 159
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 160
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 161
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 162
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 163
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 164
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 165
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 166
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 167
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 168
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 169
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 170
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 171
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 172
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 173
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 174
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 175
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 176
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 177
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 178
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 179
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 180
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 181
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 182
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 183
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 184
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 185
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 186
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 187
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 188
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 189
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 190
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 191
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 192
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 193
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 194
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 195
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 196
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 197
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 198
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 199
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 200
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 201
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 202
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 203
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 204
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 205
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 206
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 207
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 208
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 209
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 210
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 211
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 212
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 213
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 214
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 215
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 216
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 217
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 218
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 219
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 220
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 221
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 222
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 223
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 224
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 225
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 226
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 227
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 228
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 229
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 230
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 231
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 232
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 233
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 234
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 235
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 236
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 237
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 238
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 239
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 240
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 241
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 242
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 243
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 244
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 245
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 246
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 247
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 248
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 249
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 250
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 251
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 252
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 253
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 254
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 255
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 256
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 257
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 258
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 259
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 260
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 261
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 262
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 263
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 264
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 265
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 266
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 267
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 268
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 269
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 270
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 271
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 272
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 273
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 274
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 275
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 276
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 277
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 278
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 279
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 280
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 281
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 282
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 283
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 284
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 285
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 286
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 287
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 288
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 289
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 290
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 291
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 292
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 293
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 294
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 295
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 296
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 297
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 298
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 299
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 300
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 301
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 302
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 303
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 304
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 305
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 306
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 307
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 308
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 309
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 310
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 311
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 312
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 313
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 314
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 315
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 316
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 317
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 318
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 319
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 320
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 321
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 322
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 323
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 324
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 325
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 326
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 327
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 328
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 329
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 330
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 331
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 332
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 333
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 334
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 335
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 336
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 337
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 338
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 339
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 340
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 341
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 342
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 343
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 344
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 345
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 346
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 347
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 348
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 349
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 350
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 351
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 352
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 353
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 354
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 355
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 356
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 357
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 358
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 359
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 360
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 361
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 362
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 363
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 364
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 365
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 366
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 367
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 368
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 369
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 370
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 371
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 372
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 373
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 374
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 375
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 376
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 377
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 378
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 379
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 380
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 381
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 382
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 383
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 384
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 385
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 386
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 387
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 388
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 389
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 390
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 391
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 392
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 393
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 394
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 395
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 396
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 397
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 398
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 399
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 400
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 401
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 402
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 403
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 404
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 405
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 406
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 407
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 408
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 409
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 410
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 411
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 412
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 413
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 414
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 415
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 416
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 417
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 418
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 419
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 420
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 421
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 422
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 423
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 424
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 425
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 426
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 427
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 428
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 429
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 430
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 431
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 432
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 433
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 434
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 435
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 436
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 437
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 438
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 439
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 440
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 441
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 442
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 443
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 444
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 445
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 446
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 447
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 448
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 449
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 450
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 451
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 452
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 453
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 454
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 455
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 456
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 457
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 458
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 459
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 460
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 461
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 462
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 463
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 464
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 465
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 466
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 467
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 468
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 469
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 470
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 471
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 472
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 473
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 474
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 475
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 476
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 477
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 478
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 479
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 480
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 481
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 482
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 483
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 484
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 485
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 486
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 487
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 488
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 489
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 490
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 491
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 492
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 493
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 494
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 495
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 496
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 497
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 498
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 499
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 500
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 501
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 502
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 503
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 504
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 505
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 506
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 507
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 508
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 509
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 510
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 511
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 512
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 513
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 514
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 515
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 516
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 517
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 518
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 519
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 520
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 521
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 522
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 523
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 524
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 525
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 526
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 527
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 528
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 529
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 530
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 531
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 532
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 533
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 534
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 535
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 536
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 537
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 538
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 539
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 540
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 541
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 542
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 543
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 544
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 545
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 546
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 547
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 548
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 549
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 550
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 551
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 552
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 553
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 554
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 555
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 556
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 557
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 558
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 559
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 560
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 561
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 562
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 563
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 564
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 565
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 566
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 567
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 568
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 569
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 570
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 571
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 572
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 573
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 574
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 575
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 576
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 577
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 578
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 579
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 580
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 581
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 582
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 583
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 584
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 585
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 586
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 587
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 588
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 589
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 590
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 591
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 592
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 593
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 594
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 595
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 596
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 597
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 598
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 599
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 600
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 601
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 602
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 603
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 604
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 605
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 606
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 607
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 608
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 609
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 610
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 611
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 612
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 613
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 614
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 615
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 616
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 617
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 618
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 619
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 620
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 621
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 622
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 623
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 624
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 625
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 626
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 627
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 628
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 629
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 630
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 631
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 632
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 633
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 634
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 635
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 636
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 637
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 638
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 639
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 640
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 641
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 642
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 643
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 644
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 645
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 646
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 647
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 648
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 649
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 650
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 651
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 652
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 653
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 654
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 655
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 656
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 657
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 658
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 659
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 660
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 661
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 662
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 663
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 664
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 665
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 666
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 667
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 668
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 669
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 670
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 671
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 672
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 673
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 674
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 675
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 676
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 677
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 678
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 679
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 680
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 681
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 682
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 683
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 684
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 685
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 686
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 687
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 688
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 689
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 690
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 691
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 692
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 693
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 694
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 695
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 696
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 697
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 698
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 699
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 700
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 701
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 702
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 703
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 704
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 705
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 706
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 707
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 708
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 709
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 710
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 711
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 712
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 713
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 714
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 715
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 716
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 717
# Shape of bert_embedding_chunks DataFrame: (24749,)
# ...
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24518
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24519
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24520
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24521
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24522
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24523
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24524
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24525
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24526
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24527
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24528
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24529
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24530
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24531
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24532
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24533
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24534
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24535
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24536
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24537
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24538
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24539
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24540
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24541
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24542
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24543
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24544
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24545
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24546
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24547
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24548
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24549
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24550
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24551
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24552
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24553
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24554
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24555
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24556
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24557
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24558
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24559
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24560
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24561
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24562
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24563
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24564
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24565
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24566
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24567
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24568
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24569
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24570
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24571
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24572
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24573
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24574
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24575
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24576
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24577
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24578
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24579
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24580
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24581
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24582
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24583
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24584
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24585
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24586
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24587
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24588
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24589
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24590
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24591
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24592
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24593
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24594
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24595
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24596
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24597
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24598
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24599
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24600
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24601
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24602
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24603
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24604
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24605
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24606
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24607
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24608
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24609
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24610
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24611
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24612
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24613
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24614
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24615
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24616
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24617
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24618
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24619
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24620
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24621
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24622
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24623
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24624
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24625
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24626
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24627
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24628
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24629
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24630
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24631
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24632
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24633
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24634
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24635
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24636
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24637
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24638
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24639
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24640
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24641
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24642
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24643
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24644
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24645
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24646
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24647
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24648
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24649
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24650
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24651
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24652
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24653
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24654
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24655
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24656
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24657
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24658
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24659
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24660
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24661
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24662
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24663
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24664
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24665
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24666
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24667
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24668
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24669
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24670
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24671
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24672
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24673
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24674
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24675
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24676
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24677
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24678
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24679
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24680
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24681
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24682
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24683
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24684
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24685
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24686
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24687
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24688
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24689
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24690
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24691
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24692
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24693
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24694
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24695
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24696
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24697
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24698
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24699
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24700
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24701
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24702
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24703
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24704
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24705
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24706
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24707
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24708
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24709
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24710
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24711
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24712
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24713
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24714
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24715
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24716
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24717
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24718
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24719
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24720
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24721
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24722
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24723
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24724
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24725
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24726
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24727
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24728
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24729
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24730
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24731
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24732
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24733
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24734
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24735
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24736
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24737
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24738
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24739
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24740
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24741
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24742
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24743
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24744
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24745
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24746
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24747
# Shape of bert_embedding_chunks DataFrame: (24749,)
# Temp index: 24748
# Shape of bert_embedding_chunks DataFrame: (24749,)

# %%
df_30_percent_data["bert_embedding_chunks"].shape
# Out:
# (24749,)

# %%
df_30_percent_data
# Out:
#             id                                      Movies/Series  \
# 0      9464726            csi.miami.s09.e01.fallen.(2010).eng.1cd
# 1      9478254                             red.eye.(2005).eng.1cd
# 2      9367553                                  10.(2022).eng.1cd
# 3      9203091             reign.s02.e15.forbidden.(2015).eng.1cd
# 4      9265916  barbie.it.takes.two.s02.e01.weve.got.magic.to....
# ...        ...                                                ...
# 24744  9265204  the.real.housewives.of.beverly.hills.s12.e19.w...
# 24745  9492149  murdoch.mysteries.s07.e06.murdochophobia.(2013...
# 24746  9301734  dangerous.liaisons.s01.e01.love.or.war.(2022)....
# 24747  9215721  preacher.s02.e13.the.end.of.the.road.(2017).en...
# 24748  9274955    bad.sisters.s01.e10.saving.grace.(2022).eng.1cd
#
#                                                subtitles  \
# 0      [script, info, title, default, file, scripttyp...
# 1      [jet, engine, revving, anman, lets, go, anwoma...
# 2      [advertise, your, product, or, brand, here, co...
# 3      [francis, ipreviously, oni, reign, her, majest...
# 4      [advertise, your, product, or, brand, here, co...
# ...                                                  ...
# 24744  [ipreviously, oni, font, colorfffthe, real, ho...
# 24745  [i, think, thats, enough, for, today, good, no...
# 24746  [dramatic, orchestral, music, plays, indistinc...
# 24747  [use, the, free, code, joinnow, at, wwwplayshi...
# 24748  [iany, guy, playingi, watch, any, video, onlin...
#
#                                       subtitles_sentence  \
# 0      script info title default file scripttype v wr...
# 1      jet engine revving anman lets go anwoman taylo...
# 2      advertise your product or brand here contact w...
# 3      francis ipreviously oni reign her majesty mari...
# 4      advertise your product or brand here contact w...
# ...                                                  ...
# 24744  ipreviously oni font colorfffthe real housewiv...
# 24745  i think thats enough for today good now please...
# 24746  dramatic orchestral music plays indistinct cha...
# 24747  use the free code joinnow at wwwplayshipseu si...
# 24748  iany guy playingi watch any video online with ...
#
#                                           bert_embedding  \
# 0      [0.019202188, -0.10135785, 0.05124608, 0.07146...
# 1      [0.06227134, -0.15009682, 0.23519003, -0.04188...
# 2      [-0.08674303, 0.113942094, 0.07312267, -0.0547...
# 3      [0.057274677, 0.18626337, -0.005120895, -0.154...
# 4      [-0.04211163, -0.040654175, -0.010191287, -0.1...
# ...                                                  ...
# 24744  [0.14130643, -0.16698056, 0.33102593, 0.074704...
# 24745  [0.111511536, -0.026505634, 0.20732762, -0.159...
# 24746  [-0.11328379, -0.06661039, 0.11664734, 0.11008...
# 24747  [0.033705004, 0.0017321683, 0.049905933, -0.02...
# 24748  [-0.024892502, -0.14684628, 0.045202546, 0.053...
#
#                                    bert_embedding_chunks  \
# 0      [0.019202188 -0.10135785 0.05124608 0.07146899...
# 1      [0.06227134 -0.15009682 0.23519003 -0.04188167...
# 2      [-0.08674303 0.113942094 0.07312267 -0.0547033...
# 3      [0.057274677 0.18626337 -0.005120895 -0.154800...
# 4      [-0.04211163 -0.040654175 -0.010191287 -0.1076...
# ...                                                  ...
# 24744  [0.14130643 -0.16698056 0.33102593 0.0747046 -...
# 24745  [0.111511536 -0.026505634 0.20732762 -0.159436...
# 24746  [-0.11328379 -0.06661039 0.11664734 0.11008331...
# 24747  [0.033705004 0.0017321683 0.049905933 -0.02711...
# 24748  [-0.024892502 -0.14684628 0.045202546 0.053789...
#
#                                                 num_list
# 0      [9464726-0, 9464726-1, 9464726-2, 9464726-3, 9...
# 1      [9478254-0, 9478254-1, 9478254-2, 9478254-3, 9...
# 2      [9367553-0, 9367553-1, 9367553-2, 9367553-3, 9...
# 3      [9203091-0, 9203091-1, 9203091-2, 9203091-3, 9...
# 4      [9265916-0, 9265916-1, 9265916-2, 9265916-3, 9...
# ...                                                  ...
# 24744  [9265204-0, 9265204-1, 9265204-2, 9265204-3, 9...
# 24745  [9492149-0, 9492149-1, 9492149-2, 9492149-3, 9...
# 24746  [9301734-0, 9301734-1, 9301734-2, 9301734-3, 9...
# 24747  [9215721-0, 9215721-1, 9215721-2, 9215721-3, 9...
# 24748  [9274955-0, 9274955-1, 9274955-2, 9274955-3, 9...
#
# [24749 rows x 7 columns]

# %%
df_30_percent_data['num_list']
# Out:
# 0        [9464726-0, 9464726-1, 9464726-2, 9464726-3, 9...
# 1        [9478254-0, 9478254-1, 9478254-2, 9478254-3, 9...
# 2        [9367553-0, 9367553-1, 9367553-2, 9367553-3, 9...
# 3        [9203091-0, 9203091-1, 9203091-2, 9203091-3, 9...
# 4        [9265916-0, 9265916-1, 9265916-2, 9265916-3, 9...
#                                ...
# 24744    [9265204-0, 9265204-1, 9265204-2, 9265204-3, 9...
# 24745    [9492149-0, 9492149-1, 9492149-2, 9492149-3, 9...
# 24746    [9301734-0, 9301734-1, 9301734-2, 9301734-3, 9...
# 24747    [9215721-0, 9215721-1, 9215721-2, 9215721-3, 9...
# 24748    [9274955-0, 9274955-1, 9274955-2, 9274955-3, 9...
# Name: num_list, Length: 24749, dtype: object

# %% [markdown]
# ## Stroing embeddings in a ChromaDB database.

# %%
# !pip install chromadb

# %%
import chromadb

# %%
client = chromadb.PersistentClient(path='C:/Users/rjsek/OneDrive/Desktop/Search Engine Project')

# %%
collection = client.get_or_create_collection(
        name="subtitles",
        metadata={"hnsw:space": "cosine"} 
    )

# %%
collection_2 = client.get_or_create_collection(
        name="titles",
        metadata={"hnsw:space": "cosine"} 
    )

# %%
def add_func_v1():
    for i in range(df_30_percent_data.shape[0]):  # setting the range as total no. of rows in dataframe
        collection_2.add(
            documents=[df_30_percent_data['Movies/Series'].iloc[i]],  # adding each filename
            embeddings=[[1, 2, 34, 45]],  # adding a random data, as we don't need it when retrieving file_name
            ids=[df_30_percent_data['num_list'].iloc[i]]  # entering unique 'num' id
        )

# %%
def add_func_v2():
    for i in range(df_30_percent_data.shape[0]):  # setting the range as total no. of rows in dataframe
        collection.add(
            documents=df_30_percent_data['bert_embedding_chunks'].iloc[i],  # adding each chunk
            embeddings=df_30_percent_data['bert_embedding'].iloc[i],  # adding the corresponding chunk embedding
            ids=df_30_percent_data['num_list'].iloc[i]  # entering the unique 'num' id
        )

# %%
# Building Search Engine App

# %%
# VS Code

# %%
# Libraries

# %%
import re
import chromadb
from sentence_transformers import SentenceTransformer
import streamlit as st

# %%
# Initializing chromaDB

# %%
client = chromadb.PersistentClient(path="C:/Users/rjsek/OneDrive/Desktop/chroma.sqlite3")
collection = client.get_collection(name="subtitles") #test_collection 
collection_name = client.get_collection(name="titles")
model_name="paraphrase-MiniLM-L3-V2"
model = SentenceTransformer(model_name, device="cpu")

# %%
# Cleaning steps for the user query

# %%
def clean_data(data): # data is the query text
    
    #removing timestamps 
    data = re.sub("\d{2}:\d{2}:\d{2},\d{3}\s-->\s\d(2):\d{2}:\d{2},\d{3}","", data)
    #resoving index no. of dialogues 
    data = re.sub(r"\n?\d+\r", "", data)
    #removing escape sequences like \n \r 
    data = re.sub("\r|\n", "", data)
    #removing <i> and </i> 
    data = re.sub("<i>|</i>", data)
    #resoving links
    data = re.sub("(?:www.)osdb\.link\/[\w\d]+|www.OpenSubtitles\.org|osdb\.link\/ext|api\.OpenSubtitles\.org|OpenSubtitles\.com","",data)
    #Converting to lower case
    data = data.lower()
                
    #return 
    return data

# %%
# Creating a function to extract the subtitle_id

# %%
def extract_id(id_list):
    new_id_list=[]
    for item in id_list:
        match = re.match(r'^(\d+)', item)
        if match:
            extracted_number = match.group(1)
            new_id_list.append(extracted_number)
    return new_id_list

# %%
# Final VS Code [App]

# %%
import streamlit as st
import re
import pandas as pd
import chromadb
from sentence_transformers import SentenceTransformer

# Load the pre-trained SentenceTransformer model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Function to clean user query
def clean_data(data):
    # Remove punctuation and convert to lowercase
    data = re.sub(r'[^\w\s]', '', data)
    data = data.lower()
    return data

# Function to extract subtitle IDs from the 'num_list' column
def extract_id(id_list):
    return [item.split('-')[0] for item in id_list]

# Streamlit UI
st.title("🎥Movies/Series Subtitle Search Engine🔎")
search_query = st.text_input("Search here🔬")

if st.button("Search"):
    st.subheader("Subtitle Files ⬇️")
    search_query = clean_data(search_query)
    query_embed = model.encode(search_query).tolist()
    
    # Simulated query to the provided DataFrame
    df_30_percent_data = pd.read_csv("C:/Users/rjsek/Downloads/df_30_percent_data.csv")  # Replace "your_data.csv" with the actual file path
    
    # Replace this section with your actual database querying code
    # For demonstration purposes, we'll just simulate a query using the provided DataFrame
    id_list = df_30_percent_data['Movies/Series'].tolist()

    # Create a dictionary to map IDs to movie/series names
    id_to_name = df_30_percent_data.set_index('id')['Movies/Series'].to_dict()
    
    # Display the results
    for id in id_list:
        file_name = f"{id}"
        st.markdown(f"[{file_name}](https://www.opensubtitles.org/en/subtitles/{id})")
